# %%
import os
import re
import shutil
import subprocess
import pandas as pd
import numpy as np
import librosa
import soundfile as sf
from multiprocessing import Pool, cpu_count
from concurrent.futures import ThreadPoolExecutor
from joblib import Parallel, delayed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Audio Preprocessing

# %%
input_dir = "/content/drive/MyDrive/NLP_DS/processed_audio"
output_dir = "/content/drive/MyDrive/NLP_DS/final_audio"


os.makedirs(output_dir, exist_ok=True)


TARGET_SR = 22050
TARGET_FORMAT = "PCM_16"


audio_files = [f for f in os.listdir(input_dir) if f.endswith(".wav")]


def normalize_audio(audio):
    """ Normalize audio to -1 to 1 range (min-max scaling). """
    return audio / np.max(np.abs(audio))


def process_audio(file_name):
    try:
        input_path = os.path.join(input_dir, file_name)
        output_path = os.path.join(output_dir, file_name)


        audio, sr = librosa.load(input_path, sr=None, mono=False)

        if len(audio.shape) > 1:
            audio = librosa.to_mono(audio)

        if sr != TARGET_SR:
            audio = librosa.resample(audio, orig_sr=sr, target_sr=TARGET_SR)

        # Normalize audio
        audio = normalize_audio(audio)

        # Save as 16-bit WAV
        sf.write(output_path, audio, TARGET_SR, subtype=TARGET_FORMAT)

        return f"Processed: {file_name}"

    except Exception as e:
        return f"Error processing {file_name}: {str(e)}"

if __name__ == "__main__":
    num_workers = min(cpu_count(), len(audio_files))
    print(f"Processing {len(audio_files)} audio files using {num_workers} cores...")

    with Pool(num_workers) as pool:
        results = pool.map(process_audio, audio_files)

    for res in results:
        print(res)

    print("Audio preprocessing complete! All files are ready for Tacotron 2.")
# Out:
# 🔄 Processing 4538 audio files using 2 cores...
# Processed: tweet_598.wav
# Processed: tweet 3210.wav
# Processed: tweet_982.wav
# Processed: tweet 3388.wav
# Processed: tweet_2397.wav
# Processed: tweet_6191.wav
# Processed: tweet_2256.wav
# Processed: tweet_297.wav
# Processed: tweet 3202.wav
# Processed: tweet_5892.wav
# Processed: tweet 2920.wav
# Processed: tweet_6706.wav
# Processed: tweet_886.wav
# Processed: tweet_2385.wav
# Processed: tweet 3396.wav
# Processed: tweet_2511.wav
# Processed: tweet_6159.wav
# Processed: tweet_2349.wav
# Processed: tweet_5989.wav
# Processed: tweet_2191.wav
# Processed: tweet_5727.wav
# Processed: tweet_1614.wav
# Processed: tweet 2763.wav
# Processed: tweet_1830.wav
# Processed: tweet 3018.wav
# Processed: tweet 2706.wav
# Processed: tweet_262.wav
# Processed: tweet_6468.wav
# Processed: tweet_2202.wav
# Processed: tweet_6013.wav
# Processed: tweet_2135.wav
# Processed: tweet_1936.wav
# Processed: tweet 3147.wav
# Processed: tweet 3464.wav
# Processed: tweet_1305.wav
# Processed: tweet 2742.wav
# Processed: tweet_2280.wav
# Processed: tweet 3070.wav
# Processed: tweet_6112.wav
# Processed: tweet 2950.wav
# Processed: tweet_1849.wav
# Processed: tweet_753.wav
# Processed: tweet_2058.wav
# Processed: tweet_6566..wav
# Processed: tweet_644.wav
# Processed: tweet_607.wav
# Processed: tweet_2239.wav
# Processed: tweet_1463.wav
# Processed: tweet_6463.wav
# Processed: tweet_924.wav
# Processed: tweet 5620.wav
# Processed: tweet_5760.wav
# Processed: tweet 2761.wav
# Processed: tweet_5919.wav
# Processed: tweet_1350.wav
# Processed: tweet_205.wav
# Processed: tweet_1891.wav
# Processed: tweet_2508.wav
# Processed: tweet_1490.wav
# Processed: tweet_117.wav
# Processed: tweet_1819.wav
# Processed: tweet_2628.wav
# Processed: tweet_6292.wav
# Processed: tweet 3089.wav
# Processed: tweet_6678.wav
# Processed: tweet 3066.wav
# Processed: tweet_6621.wav
# Processed: tweet_6062.wav
# Processed: tweet 3206.wav
# Processed: tweet 5610.wav
# Processed: tweet_2037.wav
# Processed: tweet 3289.wav
# Processed: tweet_2308.wav
# Processed: tweet_2615.wav
# Processed: tweet_1176.wav
# Processed: tweet 5650.wav
# Processed: tweet_1941.wav
# Processed: tweet_5825.wav
# Processed: tweet_6182.wav
# Processed: tweet_2428.wav
# Processed: tweet_5965.wav
# Processed: tweet_261.wav
# Processed: tweet_1419.wav
# Processed: tweet_898.wav
# Processed: tweet_2593.wav
# Processed: tweet_1312.wav
# Processed: tweet_1545.wav
# Processed: tweet_1677.wav
# Processed: tweet_2180.wav
# Processed: tweet_1729.wav
# Processed: tweet_1123.wav
# Processed: tweet_1655.wav
# Processed: tweet_5798.wav
# Processed: tweet_66.wav
# Processed: tweet_1148.wav
# Processed: tweet 3245.wav
# Processed: tweet_660.wav
# Processed: tweet 3428.wav
# Processed: tweet_305.wav
# Processed: tweet_1385.wav
# Processed: tweet 5657.wav
# Processed: tweet_2627.wav
# Processed: tweet_1454.wav
# Processed: tweet_6414.wav
# Processed: tweet_6149.wav
# Processed: tweet_2633.wav
# Processed: tweet_837.wav
# Processed: tweet_1585.wav
# Processed: tweet_503.wav
# Processed: tweet 3525.wav
# Processed: tweet_5990.wav
# Processed: tweet_1593.wav
# Processed: tweet 2717.wav
# Processed: tweet_6186.wav
# Processed: tweet_135.wav
# Processed: tweet 2963.wav
# Processed: tweet 2975.wav
# Processed: tweet_2029.wav
# Processed: tweet 3133.wav
# Processed: tweet_5978.wav
# Processed: tweet_2260.wav
# Processed: tweet_6504.wav
# Processed: tweet_2011.wav
# Processed: tweet_989.wav
# Processed: tweet_1327.wav
# Processed: tweet_890.wav
# Processed: tweet_1408.wav
# Processed: tweet_2166.wav
# Processed: tweet_1698.wav
# Processed: tweet_1287.wav
# Processed: tweet_1920.wav
# Processed: tweet_1504.wav
# Processed: tweet 3431.wav
# Processed: tweet_2539.wav
# Processed: tweet_1710.wav
# Processed: tweet_202.wav
# Processed: tweet 3135.wav
# Processed: tweet_997.wav
# Processed: tweet_5768.wav
# Processed: tweet_625.wav
# Processed: tweet_2589.wav
# Processed: tweet_6419.wav
# Processed: tweet_1672.wav
# Processed: tweet 3220.wav
# Processed: tweet_274.wav
# Processed: tweet 3459.wav
# Processed: tweet_6045.wav
# Processed: tweet_6141.wav
# Processed: tweet_5935.wav
# Processed: tweet 3086.wav
# Processed: tweet_463.wav
# Processed: tweet_1239.wav
# Processed: tweet_5934.wav
# Processed: tweet_2653.wav
# Processed: tweet_1979.wav
# Processed: tweet_5966.wav
# Processed: tweet_6393.wav
# Processed: tweet_409.wav
# Processed: tweet_2024.wav
# Processed: tweet_871.wav
# Processed: tweet_888.wav
# Processed: tweet 3014.wav
# Processed: tweet_1374.wav
# Processed: tweet_1440.wav
# Processed: tweet_1103.wav
# Processed: tweet_1783.wav
# Processed: tweet_59.wav
# Processed: tweet_5881.wav
# Processed: tweet_6583.wav
# Processed: tweet_1054.wav
# Processed: tweet_1363.wav
# Processed: tweet_1996.wav
# Processed: tweet_1134.wav
# Processed: tweet_1682.wav
# Processed: tweet 3008.wav
# Processed: tweet_6377.wav
# Processed: tweet 3421.wav
# Processed: tweet_6134.wav
# Processed: tweet_2148.wav
# Processed: tweet_1879.wav
# Processed: tweet_1816.wav
# Processed: tweet 3497.wav
# Processed: tweet_6246.wav
# Processed: tweet_6575.wav
# Processed: tweet_915.wav
# Processed: tweet_562.wav
# Processed: tweet_6174.wav
# Processed: tweet_1398.wav
# Processed: tweet_2227.wav
# Processed: tweet 5641.wav
# Processed: tweet_6618.wav
# Processed: tweet_2115.wav
# Processed: tweet_988.wav
# Processed: tweet 3162.wav
# Processed: tweet_2395.wav
# Processed: tweet_6606.wav
# Processed: tweet_2216.wav
# Processed: tweet_2620.wav
# Processed: tweet_2415.wav
# Processed: tweet_2267.wav
# Processed: tweet 3127.wav
# Processed: tweet_6145.wav
# Processed: tweet_6724.wav
# Processed: tweet_114.wav
# Processed: tweet_664.wav
# Processed: tweet 3400.wav
# Processed: tweet_25.wav
# Processed: tweet_1053.wav
# Processed: tweet_1764.wav
# Processed: tweet 3269.wav
# Processed: tweet_1075.wav
# Processed: tweet 3376.wav
# Processed: tweet_6177.wav
# Processed: tweet_6086.wav
# Processed: tweet_2524.wav
# Processed: tweet_6309.wav
# Processed: tweet_1202.wav
# Processed: tweet_6227.wav
# Processed: tweet 3181.wav
# Processed: tweet_159.wav
# Processed: tweet_6418.wav
# Processed: tweet_5808.wav
# Processed: tweet 2728.wav
# Processed: tweet_1136.wav
# Processed: tweet_1897.wav
# Processed: tweet 3384.wav
# Processed: tweet_1133.wav
# Processed: tweet_1880.wav
# Processed: tweet_6277.wav
# Processed: tweet_1297.wav
# Processed: tweet_6339.wav
# Processed: tweet 3455.wav
# Processed: tweet_1866.wav
# Processed: tweet_804.wav
# Processed: tweet 3344.wav
# Processed: tweet_6439.wav
# Processed: tweet_2583.wav
# Processed: tweet 3342.wav
# Processed: tweet_1413.wav
# Processed: tweet_2340.wav
# Processed: tweet_2499.wav
# Processed: tweet_6691.wav
# Processed: tweet_2507.wav
# Processed: tweet 3242.wav
# Processed: tweet_1588.wav
# Processed: tweet_1997.wav
# Processed: tweet_2021.wav
# Processed: tweet_723.wav
# Processed: tweet_6527.wav
# Processed: tweet 2949.wav
# Processed: tweet 3331.wav
# Processed: tweet_6059.wav
# Processed: tweet 3041.wav
# Processed: tweet_1965.wav
# Processed: tweet 2886.wav
# Processed: tweet 3010.wav
# Processed: tweet_1119.wav
# Processed: tweet_68.wav
# Processed: tweet_5936.wav
# Processed: tweet 3424.wav
# Processed: tweet_1324.wav
# Processed: tweet_2654.wav
# Processed: tweet_6730.wav
# Processed: tweet_6293.wav
# Processed: tweet_2268.wav
# Processed: tweet_1366.wav
# Processed: tweet_6498.wav
# Processed: tweet_1566.wav
# Processed: tweet_67.wav
# Processed: tweet_6052.wav
# Processed: tweet_358.wav
# Processed: tweet_1648.wav
# Processed: tweet_2361.wav
# Processed: tweet_1068.wav
# Processed: tweet_1462.wav
# Processed: tweet_1187.wav
# Processed: tweet 3266.wav
# Processed: tweet 3401.wav
# Processed: tweet 3050.wav
# Processed: tweet_436.wav
# Processed: tweet_1836.wav
# Processed: tweet_6462.wav
# Processed: tweet 3345.wav
# Processed: tweet_2450.wav
# Processed: tweet_1967.wav
# Processed: tweet_6050.wav
# Processed: tweet_1114.wav
# Processed: tweet_599.wav
# Processed: tweet_2279.wav
# Processed: tweet_171.wav
# Processed: tweet_6613.wav
# Processed: tweet_6257.wav
# Processed: tweet_1564.wav
# Processed: tweet 2682.wav
# Processed: tweet_111.wav
# Processed: tweet_1851.wav
# Processed: tweet 5695.wav
# Processed: tweet_1221.wav
# Processed: tweet_1064.wav
# Processed: tweet_6340.wav
# Processed: tweet_1596.wav
# Processed: tweet_1569.wav
# Processed: tweet 3200.wav
# Processed: tweet_518.wav
# Processed: tweet_1949.wav
# Processed: tweet 3453.wav
# Processed: tweet_39.wav
# Processed: tweet_1522.wav
# Processed: tweet_1785.wav
# Processed: tweet_2467.wav
# Processed: tweet 3063.wav
# Processed: tweet_368.wav
# Processed: tweet_1429.wav
# Processed: tweet_1610.wav
# Processed: tweet_372.wav
# Processed: tweet_304.wav
# Processed: tweet 2656.wav
# Processed: tweet_903.wav
# Processed: tweet_6622.wav
# Processed: tweet_6012.wav
# Processed: tweet_1467.wav
# Processed: tweet_1589.wav
# Processed: tweet 3059.wav
# Processed: tweet 3003.wav
# Processed: tweet_2126.wav
# Processed: tweet_2052.wav
# Processed: tweet_77.wav
# Processed: tweet 3170.wav
# Processed: tweet 3002.wav
# Processed: tweet_1213.wav
# Processed: tweet_1956.wav
# Processed: tweet_260.wav
# Processed: tweet_1177.wav
# Processed: tweet_1723.wav
# Processed: tweet_6506.wav
# Processed: tweet 3128.wav
# Processed: tweet_51.wav
# Processed: tweet 3110.wav
# Processed: tweet_417.wav
# Processed: tweet_2297.wav
# Processed: tweet_2580.wav
# Processed: tweet_6151.wav
# Processed: tweet_811.wav
# Processed: tweet 3368.wav
# Processed: tweet_896.wav
# Processed: tweet_1680.wav
# Processed: tweet 2724.wav
# Processed: tweet_6361.wav
# Processed: tweet_2007.wav
# Processed: tweet_633.wav
# Processed: tweet_445.wav
# Processed: tweet_1505.wav
# Processed: tweet_5780.wav
# Processed: tweet_1907-1.wav
# Processed: tweet_6420.wav
# Processed: tweet_1143.wav
# Processed: tweet_502.wav
# Processed: tweet_2156.wav
# Processed: tweet_2392.wav
# Processed: tweet 5707.wav
# Processed: tweet_2550.wav
# Processed: tweet_774.wav
# Processed: tweet_1734.wav
# Processed: tweet_6009.wav
# Processed: tweet_2102.wav
# Processed: tweet_683.wav
# Processed: tweet_2611.wav
# Processed: tweet_1746.wav
# Processed: tweet_1116.wav
# Processed: tweet_6307.wav
# Processed: tweet_1706.wav
# Processed: tweet_2573.wav
# Processed: tweet_6645.wav
# Processed: tweet_453.wav
# Processed: tweet_6212.wav
# Processed: tweet_6264.wav
# Processed: tweet_393.wav
# Processed: tweet_345.wav
# Processed: tweet_1761.wav
# Processed: tweet_509.wav
# Processed: tweet_784.wav
# Processed: tweet_1402.wav
# Processed: tweet_904.wav
# Processed: tweet_1719.wav
# Processed: tweet_2520.wav
# Processed: tweet_52.wav
# Processed: tweet_6627.wav
# Processed: tweet_1873.wav
# Processed: tweet 2968.wav
# Processed: tweet_6530.wav
# Processed: tweet_2090.wav
# Processed: tweet_702.wav
# Processed: tweet_738.wav
# Processed: tweet_5886.wav
# Processed: tweet_519.wav
# Processed: tweet_5863.wav
# Processed: tweet_947.wav
# Processed: tweet_50.wav
# Processed: tweet_1061.wav
# Processed: tweet 3130.wav
# Processed: tweet 2980.wav
# Processed: tweet_6686.wav
# Processed: tweet_1676.wav
# Processed: tweet_6529.wav
# Processed: tweet_5973.wav
# Processed: tweet_329.wav
# Processed: tweet_1334.wav
# Processed: tweet_6417.wav
# Processed: tweet_573.wav
# Processed: tweet_6424.wav
# Processed: tweet_1745.wav
# Processed: tweet_5807.wav
# Processed: tweet_1940.wav
# Processed: tweet_967.wav
# Processed: tweet_6684.wav
# Processed: tweet_1775.wav
# Processed: tweet_596.wav
# Processed: tweet_1082.wav
# Processed: tweet_2265.wav
# Processed: tweet_1262.wav
# Processed: tweet_765.wav
# Processed: tweet 3246.wav
# Processed: tweet 2657.wav
# Processed: tweet 2931.wav
# Processed: tweet_6410.wav
# Processed: tweet_6143.wav
# Processed: tweet_320.wav
# Processed: tweet_6713.wav
# Processed: tweet_6711.wav
# Processed: tweet_2568.wav
# Processed: tweet_1472.wav
# Processed: tweet_2064.wav
# Processed: tweet_247.wav
# Processed: tweet_2562.wav
# Processed: tweet_356.wav
# Processed: tweet_918.wav
# Processed: tweet_1158.wav
# Processed: tweet_1708.wav
# Processed: tweet_582.wav
# Processed: tweet 2977.wav
# Processed: tweet_5996.wav
# Processed: tweet_2142.wav
# Processed: tweet_673.wav
# Processed: tweet 5652.wav
# Processed: tweet_1864.wav
# Processed: tweet_1702.wav
# Processed: tweet_2043.wav
# Processed: tweet_1392.wav
# Processed: tweet_1329.wav
# Processed: tweet 3468.wav
# Processed: tweet_646.wav
# Processed: tweet_1656.wav
# Processed: tweet_2196.wav
# Processed: tweet_1091.wav
# Processed: tweet_70.wav
# Processed: tweet_6316.wav
# Processed: tweet_2105.wav
# Processed: tweet 3383.wav
# Processed: tweet 3117.wav
# Processed: tweet_1167.wav
# Processed: tweet_5790.wav
# Processed: tweet_6593.wav
# Processed: tweet_343.wav
# Processed: tweet 3167.wav
# Processed: tweet_5943.wav
# Processed: tweet_1890.wav
# Processed: tweet_6350.wav
# Processed: tweet_6295.wav
# Processed: tweet_1004.wav
# Processed: tweet_405.wav
# Processed: tweet_2146.wav
# Processed: tweet_6465.wav
# Processed: tweet_388.wav
# Processed: tweet 5681.wav
# Processed: tweet_6215.wav
# Processed: tweet_211.wav
# Processed: tweet 3478.wav
# Processed: tweet_6008.wav
# Processed: tweet_641.wav
# Processed: tweet_510.wav
# Processed: tweet_2179.wav
# Processed: tweet_6327.wav
# Processed: tweet 3196.wav
# Processed: tweet_6079.wav
# Processed: tweet_951.wav
# Processed: tweet_6481.wav
# Processed: tweet_2547.wav
# Processed: tweet 2919.wav
# Processed: tweet_5986.wav
# Processed: tweet_6592.wav
# Processed: tweet_876.wav
# Processed: tweet 2747.wav
# Processed: tweet_5987.wav
# Processed: tweet_934.wav
# Processed: tweet 3316.wav
# Processed: tweet_2353.wav
# Processed: tweet_6406.wav
# Processed: tweet_2207.wav
# Processed: tweet_2470.wav
# Processed: tweet_55.wav
# Processed: tweet_980.wav
# Processed: tweet_401.wav
# Processed: tweet_2525.wav
# Processed: tweet_6598.wav
# Processed: tweet 3062.wav
# Processed: tweet_911.wav
# Processed: tweet_2491.wav
# Processed: tweet_1003.wav
# Processed: tweet_2445.wav
# Processed: tweet 2740.wav
# Processed: tweet_2635.wav
# Processed: tweet_5773.wav
# Processed: tweet_591.wav
# Processed: tweet_1074.wav
# Processed: tweet_678.wav
# Processed: tweet_6113.wav
# Processed: tweet 3521.wav
# Processed: tweet_495.wav
# Processed: tweet_6590.wav
# Processed: tweet_1301.wav
# Processed: tweet_1576.wav
# Processed: tweet_1428.wav
# Processed: tweet_590.wav
# Processed: tweet_6620.wav
# Processed: tweet_2379.wav
# Processed: tweet 3078.wav
# Processed: tweet 3145.wav
# Processed: tweet_1766.wav
# Processed: tweet_216.wav
# Processed: tweet_1219.wav
# Processed: tweet_1124.wav
# Processed: tweet_1222.wav
# Processed: tweet_2386.wav
# Processed: tweet_1784.wav
# Processed: tweet_909.wav
# Processed: tweet_6242.wav
# Processed: tweet_104.wav
# Processed: tweet_867.wav
# Processed: tweet_559.wav
# Processed: tweet_385.wav
# Processed: tweet 3324.wav
# Processed: tweet_2033.wav
# Processed: tweet 3456.wav
# Processed: tweet 3440.wav
# Processed: tweet_732.wav
# Processed: tweet_155.wav
# Processed: tweet_6458.wav
# Processed: tweet_5817.wav
# Processed: tweet 3111.wav
# Processed: tweet_6248.wav
# Processed: tweet_1520.wav
# Processed: tweet_6379.wav
# Processed: tweet_182.wav
# Processed: tweet_1869.wav
# Processed: tweet_44.wav
# Processed: tweet 3398.wav
# Processed: tweet_1675.wav
# Processed: tweet_6296.wav
# Processed: tweet_992.wav
# Processed: tweet_6544.wav
# Processed: tweet_899.wav
# Processed: tweet_2548.wav
# Processed: tweet_577.wav
# Processed: tweet_5912.wav
# Processed: tweet_2556.wav
# Processed: tweet 3023.wav
# Processed: tweet_402.wav
# Processed: tweet_1889.wav
# Processed: tweet_5945.wav
# Processed: tweet_161.wav
# Processed: tweet_6214.wav
# Processed: tweet_6721.wav
# Processed: tweet 3479.wav
# Processed: tweet_1875.wav
# Processed: tweet_1805.wav
# Processed: tweet 3258.wav
# Processed: tweet_1141.wav
# Processed: tweet_5820.wav
# Processed: tweet 2992.wav
# Processed: tweet_6397.wav
# Processed: tweet_5842.wav
# Processed: tweet_6247.wav
# Processed: tweet_2215.wav
# Processed: tweet 5612.wav
# Processed: tweet_6649.wav
# Processed: tweet 2922.wav
# Processed: tweet_2442.wav
# Processed: tweet 3397.wav
# Processed: tweet_6281.wav
# Processed: tweet_2332.wav
# Processed: tweet 3465.wav
# Processed: tweet_2453.wav
# Processed: tweet_2122.wav
# Processed: tweet_1662.wav
# Processed: tweet 2893.wav
# Processed: tweet_763.wav
# Processed: tweet_451.wav
# Processed: tweet_1721.wav
# Processed: tweet_1005.wav
# Processed: tweet_2480.wav
# Processed: tweet_704.wav
# Processed: tweet_5733.wav
# Processed: tweet_6436.wav
# Processed: tweet_2224.wav
# Processed: tweet_563.wav
# Processed: tweet_2310-1.wav
# Processed: tweet_1316.wav
# Processed: tweet_2261.wav
# Processed: tweet_1238.wav
# Processed: tweet_5861.wav
# Processed: tweet_6290.wav
# Processed: tweet_1982.wav
# Processed: tweet_6370.wav
# Processed: tweet 3208.wav
# Processed: tweet 5614.wav
# Processed: tweet 2908.wav
# Processed: tweet_2579.wav
# Processed: tweet_841.wav
# Processed: tweet_768.wav
# Processed: tweet 5718.wav
# Processed: tweet 3154.wav
# Processed: tweet_2590.wav
# Processed: tweet_6081.wav
# Processed: tweet_1518.wav
# Processed: tweet_53.wav
# Processed: tweet_6007.wav
# Processed: tweet 2945.wav
# Processed: tweet_1798.wav
# Processed: tweet_6133.wav
# Processed: tweet_1820.wav
# Processed: tweet_1513.wav
# Processed: tweet_1251.wav
# Processed: tweet 3296.wav
# Processed: tweet 3476.wav
# Processed: tweet_6260.wav
# Processed: tweet_2199.wav
# Processed: tweet_6351.wav
# Processed: tweet_1862.wav
# Processed: tweet_681.wav
# Processed: tweet_1749.wav
# Processed: tweet_1938.wav
# Processed: tweet_2248.wav
# Processed: tweet_698.wav
# Processed: tweet_665.wav
# Processed: tweet_6348.wav
# Processed: tweet 3343.wav
# Processed: tweet 3470.wav
# Processed: tweet_6507.wav
# Processed: tweet_6302.wav
# Processed: tweet_906.wav
# Processed: tweet_6522.wav
# Processed: tweet_1471.wav
# Processed: tweet_5763.wav
# Processed: tweet_221.wav
# Processed: tweet_2272.wav
# Processed: tweet_614.wav
# Processed: tweet_630.wav
# Processed: tweet_1174.wav
# Processed: tweet_5728.wav
# Processed: tweet 3243.wav
# Processed: tweet_1468.wav
# Processed: tweet_6042.wav
# Processed: tweet_73.wav
# Processed: tweet_958.wav
# Processed: tweet 3065.wav
# Processed: tweet_1294.wav
# Processed: tweet_655.wav
# Processed: tweet_1125.wav
# Processed: tweet 3373.wav
# Processed: tweet 3374.wav
# Processed: tweet 2751.wav
# Processed: tweet_2344.wav
# Processed: tweet_2270.wav
# Processed: tweet_399.wav
# Processed: tweet_6263.wav
# Processed: tweet_307.wav
# Processed: tweet 2677.wav
# Processed: tweet_489.wav
# Processed: tweet_2164.wav
# Processed: tweet 2938.wav
# Processed: tweet_6173.wav
# Processed: tweet_2269.wav
# Processed: tweet_5805.wav
# Processed: tweet 2661.wav
# Processed: tweet 5682.wav
# Processed: tweet_1912.wav
# Processed: tweet_944.wav
# Processed: tweet 5689.wav
# Processed: tweet_6596.wav
# Processed: tweet_2561.wav
# Processed: tweet_2249.wav
# Processed: tweet_2305.wav
# Processed: tweet_843.wav
# Processed: tweet_2371.wav
# Processed: tweet_2084.wav
# Processed: tweet_5853.wav
# Processed: tweet_539.wav
# Processed: tweet_2330.wav
# Processed: tweet_6099.wav
# Processed: tweet_1722.wav
# Processed: tweet_639.wav
# Processed: tweet 3129.wav
# Processed: tweet 5773.wav
# Processed: tweet 5619.wav
# Processed: tweet_1233.wav
# Processed: tweet_173.wav
# Processed: tweet 3180.wav
# Processed: tweet 2759.wav
# Processed: tweet 3124.wav
# Processed: tweet_367.wav
# Processed: tweet_498.wav
# Processed: tweet_859.wav
# Processed: tweet_239.wav
# Processed: tweet_2516.wav
# Processed: tweet_6069.wav
# Processed: tweet_1370.wav
# Processed: tweet_688.wav
# Processed: tweet_5834.wav
# Processed: tweet_543.wav
# Processed: tweet_1104.wav
# Processed: tweet_1587.wav
# Processed: tweet_257.wav
# Processed: tweet_277.wav
# Processed: tweet_1911.wav
# Processed: tweet 3178.wav
# Processed: tweet_1200.wav
# Processed: tweet_912.wav
# Processed: tweet_1844.wav
# Processed: tweet_1925.wav
# Processed: tweet_2436.wav
# Processed: tweet_6641.wav
# Processed: tweet_6690.wav
# Processed: tweet_462.wav
# Processed: tweet_744.wav
# Processed: tweet 3166.wav
# Processed: tweet_626.wav
# Processed: tweet_333.wav
# Processed: tweet_6671.wav
# Processed: tweet_6024.wav
# Processed: tweet_1434.wav
# Processed: tweet_566.wav
# Processed: tweet_6326.wav
# Processed: tweet_1917.wav
# Processed: tweet 3294.wav
# Processed: tweet_6708.wav
# Processed: tweet_587.wav
# Processed: tweet_6116.wav
# Processed: tweet_6345.wav
# Processed: tweet_6195.wav
# Processed: tweet_533.wav
# Processed: tweet 5640.wav
# Processed: tweet_1848.wav
# Processed: tweet_2288.wav
# Processed: tweet_357.wav
# Processed: tweet_1276.wav
# Processed: tweet_1542.wav
# Processed: tweet_5786.wav
# Processed: tweet_928.wav
# Processed: tweet 2689.wav
# Processed: tweet 2995.wav
# Processed: tweet_2192.wav
# Processed: tweet_6097.wav
# Processed: tweet_120.wav
# Processed: tweet 3095.wav
# Processed: tweet_6583 .wav
# Processed: tweet 3055.wav
# Processed: tweet_1963.wav
# Processed: tweet_2026.wav
# Processed: tweet_5864.wav
# Processed: tweet 5692.wav
# Processed: tweet_1526.wav
# Processed: tweet_973.wav
# Processed: tweet_5776.wav
# Processed: tweet_1178.wav
# Processed: tweet_733.wav
# Processed: tweet_864.wav
# Processed: tweet 2944.wav
# Processed: tweet_2557.wav
# Processed: tweet_1418.wav
# Processed: tweet_1105.wav
# Processed: tweet_1406.wav
# Processed: tweet_5731.wav
# Processed: tweet 3366.wav
# Processed: tweet_6383.wav
# Processed: tweet_433.wav
# Processed: tweet_1752.wav
# Processed: tweet_640.wav
# Processed: tweet_5752.wav
# Processed: tweet_2221.wav
# Processed: tweet_826.wav
# Processed: tweet_2357.wav
# Processed: tweet_659.wav
# Processed: tweet_847.wav
# Processed: tweet_1129.wav
# Processed: tweet_1747.wav
# Processed: tweet_6636.wav
# Processed: tweet 3247.wav
# Processed: tweet_6558.wav
# Processed: tweet 3473.wav
# Processed: tweet 3115.wav
# Processed: tweet_1441.wav
# Processed: tweet_1779.wav
# Processed: tweet_2483.wav
# Processed: tweet 3329.wav
# Processed: tweet_2624.wav
# Processed: tweet_466.wav
# Processed: tweet 2698.wav
# Processed: tweet_1390.wav
# Processed: tweet_6501.wav
# Processed: tweet_6479.wav
# Processed: tweet_2510.wav
# Processed: tweet 5710.wav
# Processed: tweet_6253.wav
# Processed: tweet_268.wav
# Processed: tweet_1918.wav
# Processed: tweet_1769.wav
# Processed: tweet_1172.wav
# Processed: tweet_2400.wav
# Processed: tweet 5708.wav
# Processed: tweet_5968.wav
# Processed: tweet_6670.wav
# Processed: tweet 3051.wav
# Processed: tweet_331.wav
# Processed: tweet 2757.wav
# Processed: tweet_219.wav
# Processed: tweet_6049.wav
# Processed: tweet_1027.wav
# Processed: tweet_6496.wav
# Processed: tweet_2423.wav
# Processed: tweet 3090.wav
# Processed: tweet 3507.wav
# Processed: tweet_604.wav
# Processed: tweet_6125.wav
# Processed: tweet_1362.wav
# Processed: tweet_2322.wav
# Processed: tweet_887.wav
# Processed: tweet_6502.wav
# Processed: tweet 2967.wav
# Processed: tweet_6122.wav
# Processed: tweet_6680.wav
# Processed: tweet_6405.wav
# Processed: tweet_2056.wav
# Processed: tweet_1380.wav
# Processed: tweet_631.wav
# Processed: tweet 3182.wav
# Processed: tweet_419.wav
# Processed: tweet_6006.wav
# Processed: tweet_2271.wav
# Processed: tweet 3148.wav
# Processed: tweet_4.wav
# Processed: tweet_6102.wav
# Processed: tweet 5775.wav
# Processed: tweet 3079.wav
# Processed: tweet_6153.wav
# Processed: tweet_726.wav
# Processed: tweet_2004.wav
# Processed: tweet_2358.wav
# Processed: tweet_5753.wav
# Processed: tweet_1573.wav
# Processed: tweet 2890.wav
# Processed: tweet_6106.wav
# Processed: tweet 3527.wav
# Processed: tweet_1387.wav
# Processed: tweet_6193.wav
# Processed: tweet 2729.wav
# Processed: tweet 2984.wav
# Processed: tweet_799.wav
# Processed: tweet_242.wav
# Processed: tweet_1388.wav
# Processed: tweet_5812.wav
# Processed: tweet_1994.wav
# Processed: tweet_339.wav
# Processed: tweet_1933.wav
# Processed: tweet_426.wav
# Processed: tweet 5680.wav
# Processed: tweet_1807.wav
# Processed: tweet_742.wav
# Processed: tweet_1531.wav
# Processed: tweet_5795.wav
# Processed: tweet 2953.wav
# Processed: tweet_1039.wav
# Processed: tweet_6384.wav
# Processed: tweet 3495.wav
# Processed: tweet_1166 - Copy.wav
# Processed: tweet_2572.wav
# Processed: tweet_6017.wav
# Processed: tweet_1373.wav
# Processed: tweet_874.wav
# Processed: tweet 3099.wav
# Processed: tweet_65.wav
# Processed: tweet_990.wav
# Processed: tweet_2057.wav
# Processed: tweet 3318.wav
# Processed: tweet 2672.wav
# Processed: tweet_6306.wav
# Processed: tweet 3060.wav
# Processed: tweet 2739.wav
# Processed: tweet_5984.wav
# Processed: tweet 3446.wav
# Processed: tweet_1470.wav
# Processed: tweet_6343.wav
# Processed: tweet_570.wav
# Processed: tweet_231.wav
# Processed: tweet_1598.wav
# Processed: tweet 3021.wav
# Processed: tweet_2519.wav
# Processed: tweet_932.wav
# Processed: tweet 3122.wav
# Processed: tweet_2242.wav
# Processed: tweet_5915.wav
# Processed: tweet_532.wav
# Processed: tweet 3299.wav
# Processed: tweet_5942.wav
# Processed: tweet 2753.wav
# Processed: tweet 5704.wav
# Processed: tweet 3032.wav
# Processed: tweet_6584.wav
# Processed: tweet_1281.wav
# Processed: tweet_476.wav
# Processed: tweet 2681.wav
# Processed: tweet_1985.wav
# Processed: tweet_6127.wav
# Processed: tweet_5873.wav
# Processed: tweet_6640.wav
# Processed: tweet_2610.wav
# Processed: tweet_6000.wav
# Processed: tweet_1420.wav
# Processed: tweet_6619.wav
# Processed: tweet 2969.wav
# Processed: tweet_5914.wav
# Processed: tweet_49.wav
# Processed: tweet_6231.wav
# Processed: tweet_2003.wav
# Processed: tweet_5761.wav
# Processed: tweet_2641.wav
# Processed: tweet_6258.wav
# Processed: tweet_1205.wav
# Processed: tweet_127.wav
# Processed: tweet_353.wav
# Processed: tweet_1048.wav
# Processed: tweet_905.wav
# Processed: tweet 3158.wav
# Processed: tweet_868.wav
# Processed: tweet 2948.wav
# Processed: tweet_18.wav
# Processed: tweet 5694.wav
# Processed: tweet_1999.wav
# Processed: tweet_6470.wav
# Processed: tweet 3020.wav
# Processed: tweet_5904.wav
# Processed: tweet_1817.wav
# Processed: tweet_1288.wav
# Processed: tweet 5712.wav
# Processed: tweet_2494.wav
# Processed: tweet 5717.wav
# Processed: tweet_1144.wav
# Processed: tweet_199.wav
# Processed: tweet_769.wav
# Processed: tweet 5648.wav
# Processed: tweet_481.wav
# Processed: tweet_6142.wav
# Processed: tweet_1590.wav
# Processed: tweet 5611.wav
# Processed: tweet_2201.wav
# Processed: tweet_6188.wav
# Processed: tweet_2612.wav
# Processed: tweet_2473.wav
# Processed: tweet_1122.wav
# Processed: tweet_1058.wav
# Processed: tweet_527.wav
# Processed: tweet 3057.wav
# Processed: tweet_6704.wav
# Processed: tweet_1265.wav
# Processed: tweet_5762.wav
# Processed: tweet_6285.wav
# Processed: tweet_1740.wav
# Processed: tweet_57.wav
# Processed: tweet_1383.wav
# Processed: tweet_1336.wav
# Processed: tweet_5992.wav
# Processed: tweet_5815.wav
# Processed: tweet_2121.wav
# Processed: tweet_6110.wav
# Processed: tweet 3330.wav
# Processed: tweet_2157.wav
# Processed: tweet_2408.wav
# Processed: tweet_6716.wav
# Processed: tweet_1482.wav
# Processed: tweet_1224.wav
# Processed: tweet_1237.wav
# Processed: tweet_6599.wav
# Processed: tweet 3026.wav
# Processed: tweet_770.wav
# Processed: tweet_2484.wav
# Processed: tweet_1073.wav
# Processed: tweet_1459.wav
# Processed: tweet 5613.wav
# Processed: tweet 3308.wav
# Processed: tweet_6252.wav
# Processed: tweet 3315.wav
# Processed: tweet_6048.wav
# Processed: tweet 3448.wav
# Processed: tweet_6146.wav
# Processed: tweet 3175.wav
# Processed: tweet 5625.wav
# Processed: tweet_2291.wav
# Processed: tweet_1232.wav
# Processed: tweet_5740.wav
# Processed: tweet_5738.wav
# Processed: tweet_2042.wav
# Processed: tweet_2356.wav
# Processed: tweet 2906.wav
# Processed: tweet_798.wav
# Processed: tweet_1486.wav
# Processed: tweet_1976.wav
# Processed: tweet_6594.wav
# Processed: tweet_1293.wav
# Processed: tweet_538.wav
# Processed: tweet_1887.wav
# Processed: tweet_2459.wav
# Processed: tweet_5880.wav
# Processed: tweet_5887.wav
# Processed: tweet_6469.wav
# Processed: tweet_1407.wav
# Processed: tweet_2001.wav
# Processed: tweet_1217.wav
# Processed: tweet_146.wav
# Processed: tweet_1727.wav
# Processed: tweet_5856.wav
# Processed: tweet_541.wav
# Processed: tweet_6516.wav
# Processed: tweet 5637.wav
# Processed: tweet_6707.wav
# Processed: tweet_6330.wav
# Processed: tweet 3212.wav
# Processed: tweet_694.wav
# Processed: tweet_151.wav
# Processed: tweet_2074.wav
# Processed: tweet_1052.wav
# Processed: tweet_816.wav
# Processed: tweet 3061.wav
# Processed: tweet 2899.wav
# Processed: tweet_5899.wav
# Processed: tweet_5878.wav
# Processed: tweet_6082.wav
# Processed: tweet_5754.wav
# Processed: tweet_6565.wav
# Processed: tweet_1130.wav
# Processed: tweet_2304.wav
# Processed: tweet_6682.wav
# Processed: tweet_1937.wav
# Processed: tweet_658.wav
# Processed: tweet_878.wav
# Processed: tweet_1369.wav
# Processed: tweet_2222.wav
# Processed: tweet 2896.wav
# Processed: tweet_1580.wav
# Processed: tweet 3389.wav
# Processed: tweet_6595.wav
# Processed: tweet_5802.wav
# Processed: tweet_6299.wav
# Processed: tweet_30.wav
# Processed: tweet_154.wav
# Processed: tweet_469.wav
# Processed: tweet 3463.wav
# Processed: tweet_687.wav
# Processed: tweet 2673.wav
# Processed: tweet_2086.wav
# Processed: tweet_2177.wav
# Processed: tweet_6398.wav
# Processed: tweet_478.wav
# Processed: tweet_425.wav
# Processed: tweet_2393.wav
# Processed: tweet_1464.wav
# Processed: tweet_740.wav
# Processed: tweet 3429.wav
# Processed: tweet_126.wav
# Processed: tweet_1489.wav
# Processed: tweet 3512.wav
# Processed: tweet_1742.wav
# Processed: tweet_2208.wav
# Processed: tweet_1693.wav
# Processed: tweet_6002.wav
# Processed: tweet_1393.wav
# Processed: tweet 3435.wav
# Processed: tweet_134.wav
# Processed: tweet_6648.wav
# Processed: tweet 2898.wav
# Processed: tweet 3443.wav
# Processed: tweet_1146.wav
# Processed: tweet_354.wav
# Processed: tweet_2581.wav
# Processed: tweet 3445.wav
# Processed: tweet_115.wav
# Processed: tweet_214.wav
# Processed: tweet_1995.wav
# Processed: tweet_454.wav
# Processed: tweet 3199.wav
# Processed: tweet_858.wav
# Processed: tweet_275.wav
# Processed: tweet_6317.wav
# Processed: tweet_1049.wav
# Processed: tweet_2123.wav
# Processed: tweet 3485.wav
# Processed: tweet 3004.wav
# Processed: tweet_815.wav
# Processed: tweet_6666.wav
# Processed: tweet 3323.wav
# Processed: tweet_2488.wav
# Processed: tweet_611.wav
# Processed: tweet 3209.wav
# Processed: tweet 2702.wav
# Processed: tweet 2734.wav
# Processed: tweet_6710.wav
# Processed: tweet 3509.wav
# Processed: tweet_102.wav
# Processed: tweet 5703.wav
# Processed: tweet_6408.wav
# Processed: tweet_406.wav
# Processed: tweet_1342.wav
# Processed: tweet_1090.wav
# Processed: tweet_1112.wav
# Processed: tweet_6518.wav
# Processed: tweet_6535.wav
# Processed: tweet 3395.wav
# Processed: tweet_975.wav
# Processed: tweet_1633.wav
# Processed: tweet_6395.wav
# Processed: tweet_2345.wav
# Processed: tweet_1543.wav
# Processed: tweet_998.wav
# Processed: tweet_5746.wav
# Processed: tweet_2114.wav
# Processed: tweet_5810.wav
# Processed: tweet_461.wav
# Processed: tweet_2401.wav
# Processed: tweet_6236.wav
# Processed: tweet_1038.wav
# Processed: tweet_440.wav
# Processed: tweet_470.wav
# Processed: tweet 3285.wav
# Processed: tweet_438.wav
# Processed: tweet_1164.wav
# Processed: tweet 3143.wav
# Processed: tweet 3513.wav
# Processed: tweet_6150.wav
# Processed: tweet_788.wav
# Processed: tweet 3379.wav
# Processed: tweet 3073.wav
# Processed: tweet_1032.wav
# Processed: tweet_1250.wav
# Processed: tweet_485.wav
# Processed: tweet 2979.wav
# Processed: tweet_6688.wav
# Processed: tweet_2456.wav
# Processed: tweet_900.wav
# Processed: tweet 3320.wav
# Processed: tweet 3215.wav
# Processed: tweet_1196.wav
# Processed: tweet 3176.wav
# Processed: tweet_1625.wav
# Processed: tweet 2983.wav
# Processed: tweet_672.wav
# Processed: tweet_2527.wav
# Processed: tweet_448.wav
# Processed: tweet 2671.wav
# Processed: tweet_2476.wav
# Processed: tweet_213.wav
# Processed: tweet_6204.wav
# Processed: tweet_2069.wav
# Processed: tweet_2546.wav
# Processed: tweet_6401.wav
# Processed: tweet 2924.wav
# Processed: tweet_600.wav
# Processed: tweet_6692.wav
# Processed: tweet_40.wav
# Processed: tweet_234.wav
# Processed: tweet 3458.wav
# Processed: tweet_1354.wav
# Processed: tweet_1284.wav
# Processed: tweet 3426.wav
# Processed: tweet_1539.wav
# Processed: tweet_6605.wav
# Processed: tweet_5783.wav
# Processed: tweet_1694.wav
# Processed: tweet_1381.wav
# Processed: tweet_2217.wav
# Processed: tweet 2996.wav
# Processed: tweet_6681.wav
# Processed: tweet_5896.wav
# Processed: tweet_1184.wav
# Processed: tweet_1169.wav
# Processed: tweet_1424.wav
# Processed: tweet_2387.wav
# Processed: tweet_6650.wav
# Processed: tweet_1278.wav
# Processed: tweet_758.wav
# Processed: tweet 3071.wav
# Processed: tweet_296.wav
# Processed: tweet_299.wav
# Processed: tweet_2421.wav
# Processed: tweet_145.wav
# Processed: tweet 5693.wav
# Processed: tweet_1086.wav
# Processed: tweet_5804.wav
# Processed: tweet 2986.wav
# Processed: tweet_1991.wav
# Processed: tweet_540.wav
# Processed: tweet_82.wav
# Processed: tweet_184.wav
# Processed: tweet_475.wav
# Processed: tweet_5930.wav
# Processed: tweet_6266.wav
# Processed: tweet_771.wav
# Processed: tweet_493.wav
# Processed: tweet_1242.wav
# Processed: tweet_2013.wav
# Processed: tweet_2117.wav
# Processed: tweet_6021.wav
# Processed: tweet_2006.wav
# Processed: tweet 3236.wav
# Processed: tweet_6211.wav
# Processed: tweet_6363.wav
# Processed: tweet 2693.wav
# Processed: tweet_6033.wav
# Processed: tweet_6183.wav
# Processed: tweet_266.wav
# Processed: tweet 3187.wav
# Processed: tweet_1495.wav
# Processed: tweet_1084.wav
# Processed: tweet_1171.wav
# Processed: tweet_2342.wav
# Processed: tweet_5778.wav
# Processed: tweet_474.wav
# Processed: tweet_5913.wav
# Processed: tweet_1271.wav
# Processed: tweet_850.wav
# Processed: tweet_6268.wav
# Processed: tweet 2939.wav
# Processed: tweet_6241.wav
# Processed: tweet_5870.wav
# Processed: tweet_13.wav
# Processed: tweet_2427.wav
# Processed: tweet_1391.wav
# Processed: tweet_2438.wav
# Processed: tweet_6483.wav
# Processed: tweet_1079.wav
# Processed: tweet 3422.wav
# Processed: tweet 3278.wav
# Processed: tweet_178.wav
# Processed: tweet 3405.wav
# Processed: tweet_5821.wav
# Processed: tweet_6375.wav
# Processed: tweet_514.wav
# Processed: tweet 2915.wav
# Processed: tweet_1042.wav
# Processed: tweet_1771.wav
# Processed: tweet_2120.wav
# Processed: tweet_1792.wav
# Processed: tweet_2315.wav
# Processed: tweet_2275.wav
# Processed: tweet_6644.wav
# Processed: tweet_6360.wav
# Processed: tweet_6023.wav
# Processed: tweet_1257.wav
# Processed: tweet_767.wav
# Processed: tweet_1645.wav
# Processed: tweet 3480.wav
# Processed: tweet 3265.wav
# Processed: tweet_6094.wav
# Processed: tweet_370.wav
# Processed: tweet_822.wav
# Processed: tweet_2101-1.wav
# Processed: tweet_270.wav
# Processed: tweet_1950.wav
# Processed: tweet 2684.wav
# Processed: tweet_1856.wav
# Processed: tweet_2545.wav
# Processed: tweet 3360.wav
# Processed: tweet_5777.wav
# Processed: tweet 5700.wav
# Processed: tweet_6547.wav
# Processed: tweet_310.wav
# Processed: tweet_1780.wav
# Processed: tweet 3287.wav
# Processed: tweet_89.wav
# Processed: tweet_974.wav
# Processed: tweet_2407.wav
# Processed: tweet_656.wav
# Processed: tweet 3274.wav
# Processed: tweet_5997.wav
# Processed: tweet_1193.wav
# Processed: tweet_1583.wav
# Processed: tweet_832.wav
# Processed: tweet_6068.wav
# Processed: tweet_1986.wav
# Processed: tweet_1307.wav
# Processed: tweet_6625.wav
# Processed: tweet_6148.wav
# Processed: tweet_1431.wav
# Processed: tweet_6629.wav
# Processed: tweet_2047.wav
# Processed: tweet_6203.wav
# Processed: tweet_6499.wav
# Processed: tweet_5999.wav
# Processed: tweet_6517.wav
# Processed: tweet 3529.wav
# Processed: tweet_6655.wav
# Processed: tweet_511.wav
# Processed: tweet_745.wav
# Processed: tweet_2549.wav
# Processed: tweet_2538.wav
# Processed: tweet_1326.wav
# Processed: tweet_9.wav
# Processed: tweet_6178.wav
# Processed: tweet_2099.wav
# Processed: tweet_81.wav
# Processed: tweet_2404.wav
# Processed: tweet_757.wav
# Processed: tweet_5779.wav
# Processed: tweet 3169.wav
# Processed: tweet_2591.wav
# Processed: tweet_6376.wav
# Processed: tweet_2370.wav
# Processed: tweet 2901.wav
# Processed: tweet_6093.wav
# Processed: tweet_553.wav
# Processed: tweet_827.wav
# Processed: tweet 2707.wav
# Processed: tweet_1626.wav
# Processed: tweet_1794.wav
# Processed: tweet 3534.wav
# Processed: tweet_825.wav
# Processed: tweet_6194.wav
# Processed: tweet_1586.wav
# Processed: tweet_6614.wav
# Processed: tweet_119.wav
# Processed: tweet_1070.wav
# Processed: tweet_6723.wav
# Processed: tweet_1149.wav
# Processed: tweet_6304.wav
# Processed: tweet_2354.wav
# Processed: tweet 3100.wav
# Processed: tweet_5921.wav
# Processed: tweet_1448.wav
# Processed: tweet_2210.wav
# Processed: tweet_236.wav
# Processed: tweet_1958.wav
# Processed: tweet_5729.wav
# Processed: tweet_6034.wav
# Processed: tweet_6356.wav
# Processed: tweet_5840.wav
# Processed: tweet_6508.wav
# Processed: tweet_5749.wav
# Processed: tweet_616.wav
# Processed: tweet_5770.wav
# Processed: tweet_414.wav
# Processed: tweet_2020.wav
# Processed: tweet_6658.wav
# Processed: tweet_1592.wav
# Processed: tweet 3349.wav
# Processed: tweet_1650.wav
# Processed: tweet_2168.wav
# Processed: tweet_2301.wav
# Processed: tweet 5769.wav
# Processed: tweet_677.wav
# Processed: tweet_166.wav
# Processed: tweet_1317.wav
# Processed: tweet_6367.wav
# Processed: tweet 3528.wav
# Processed: tweet_6683.wav
# Processed: tweet 3532.wav
# Processed: tweet 3082.wav
# Processed: tweet_26.wav
# Processed: tweet 3514.wav
# Processed: tweet_2469.wav
# Processed: tweet_1248.wav
# Processed: tweet_2500.wav
# Processed: tweet_6546.wav
# Processed: tweet_1268.wav
# Processed: tweet_1013.wav
# Processed: tweet_2626.wav
# Processed: tweet 3186.wav
# Processed: tweet_583.wav
# Processed: tweet_172.wav
# Processed: tweet 3491.wav
# Processed: tweet_302.wav
# Processed: tweet 3288.wav
# Processed: tweet_1968.wav
# Processed: tweet 2960.wav
# Processed: tweet_2285.wav
# Processed: tweet 3319.wav
# Processed: tweet 2735.wav
# Processed: tweet_1715.wav
# Processed: tweet_676.wav
# Processed: tweet_2426.wav
# Processed: tweet 5719.wav
# Processed: tweet 3190.wav
# Processed: tweet 3314.wav
# Processed: tweet_5751.wav
# Processed: tweet_1323.wav
# Processed: tweet 5621.wav
# Processed: tweet_1321.wav
# Processed: tweet_6572.wav
# Processed: tweet_2289.wav
# Processed: tweet_2424.wav
# Processed: tweet 2762.wav
# Processed: tweet_6509.wav
# Processed: tweet_1992.wav
# Processed: tweet_568.wav
# Processed: tweet_2376.wav
# Processed: tweet_5767.wav
# Processed: tweet_1120.wav
# Processed: tweet_939.wav
# Processed: tweet_2333.wav
# Processed: tweet_6474.wav
# Processed: tweet_6358.wav
# Processed: tweet 3354.wav
# Processed: tweet_19.wav
# Processed: tweet_993.wav
# Processed: tweet_2231.wav
# Processed: tweet_6140.wav
# Processed: tweet_149.wav
# Processed: tweet 3221.wav
# Processed: tweet_6297.wav
# Processed: tweet_2604.wav
# Processed: tweet_201.wav
# Processed: tweet_6276.wav
# Processed: tweet_605.wav
# Processed: tweet_2015.wav
# Processed: tweet_410.wav
# Processed: tweet_2143.wav
# Processed: tweet_2244.wav
# Processed: tweet_2287.wav
# Processed: tweet_1947.wav
# Processed: tweet_1181.wav
# Processed: tweet 2712.wav
# Processed: tweet_241.wav
# Processed: tweet 3226.wav
# Processed: tweet_6579.wav
# Processed: tweet 5725.wav
# Processed: tweet_1156.wav
# Processed: tweet_6232.wav
# Processed: tweet 5715.wav
# Processed: tweet_165.wav
# Processed: tweet_1377.wav
# Processed: tweet_1795.wav
# Processed: tweet_2118.wav
# Processed: tweet 3146.wav
# Processed: tweet_110.wav
# Processed: tweet_1198.wav
# Processed: tweet_2530.wav
# Processed: tweet_1574.wav
# Processed: tweet 2732.wav
# Processed: tweet_1654.wav
# Processed: tweet_2092.wav
# Processed: tweet_5890.wav
# Processed: tweet 3216.wav
# Processed: tweet_1685.wav
# Processed: tweet 2976.wav
# Processed: tweet 2705.wav
# Processed: tweet 2744.wav
# Processed: tweet_1118.wav
# Processed: tweet_1908.wav
# Processed: tweet_1364.wav
# Processed: tweet_6220.wav
# Processed: tweet_731.wav
# Processed: tweet_1394.wav
# Processed: tweet_6119.wav
# Processed: tweet_6534.wav
# Processed: tweet_516.wav
# Processed: tweet 3454.wav
# Processed: tweet_2173.wav
# Processed: tweet_106.wav
# Processed: tweet 2985.wav
# Processed: tweet_728.wav
# Processed: tweet_1858.wav
# Processed: tweet_2181.wav
# Processed: tweet 3230.wav
# Processed: tweet 3449.wav
# Processed: tweet_1516.wav
# Processed: tweet 2678.wav
# Processed: tweet_181.wav
# Processed: tweet_1161.wav
# Processed: tweet_6090.wav
# Processed: tweet_5741.wav
# Processed: tweet_1786.wav
# Processed: tweet 3489.wav
# Processed: tweet 3333.wav
# Processed: tweet_1253.wav
# Processed: tweet 3436.wav
# Processed: tweet 3250.wav
# Processed: tweet_715.wav
# Processed: tweet 5656.wav
# Processed: tweet_787.wav
# Processed: tweet_6287.wav
# Processed: tweet 2771.wav
# Processed: tweet_622.wav
# Processed: tweet_289.wav
# Processed: tweet_2187.wav
# Processed: tweet_1660.wav
# Processed: tweet_6526.wav
# Processed: tweet_210.wav
# Processed: tweet_407.wav
# Processed: tweet 2891.wav
# Processed: tweet_1861.wav
# Processed: tweet_6001.wav
# Processed: tweet_536.wav
# Processed: tweet_5888.wav
# Processed: tweet 3357.wav
# Processed: tweet 5723.wav
# Processed: tweet_2647.wav
# Processed: tweet_783.wav
# Processed: tweet_1175.wav
# Processed: tweet_6551.wav
# Processed: tweet_6717.wav
# Processed: tweet_344.wav
# Processed: tweet_2112.wav
# Processed: tweet_2560.wav
# Processed: tweet 3256.wav
# Processed: tweet_2040.wav
# Processed: tweet 2669.wav
# Processed: tweet_6623.wav
# Processed: tweet_2552.wav
# Processed: tweet_5969.wav
# Processed: tweet_6320.wav
# Processed: tweet_1153.wav
# Processed: tweet 2683.wav
# Processed: tweet 5636.wav
# Processed: tweet_418.wav
# Processed: tweet_2095.wav
# Processed: tweet_2446.wav
# Processed: tweet_5.wav
# Processed: tweet 3466.wav
# Processed: tweet_684.wav
# Processed: tweet_1264.wav
# Processed: tweet_2339.wav
# Processed: tweet_1726.wav
# Processed: tweet_1478.wav
# Processed: tweet_278.wav
# Processed: tweet_5940.wav
# Processed: tweet_722.wav
# Processed: tweet_384.wav
# Processed: tweet_686.wav
# Processed: tweet 5631.wav
# Processed: tweet_935.wav
# Processed: tweet_1270.wav
# Processed: tweet_6025.wav
# Processed: tweet_1154.wav
# Processed: tweet_1559.wav
# Processed: tweet_435.wav
# Processed: tweet_225.wav
# Processed: tweet_1638.wav
# Processed: tweet_721.wav
# Processed: tweet 3094.wav
# Processed: tweet_2475.wav
# Processed: tweet_1121.wav
# Processed: tweet_1345.wav
# Processed: tweet_141.wav
# Processed: tweet_817.wav
# Processed: tweet_6366.wav
# Processed: tweet_2355.wav
# Processed: tweet_1724.wav
# Processed: tweet 3241.wav
# Processed: tweet_851.wav
# Processed: tweet_1396.wav
# Processed: tweet_892.wav
# Processed: tweet_96.wav
# Processed: tweet_1306.wav
# Processed: tweet 5643.wav
# Processed: tweet 3382.wav
# Processed: tweet_1017.wav
# Processed: tweet_592.wav
# Processed: tweet_2085.wav
# Processed: tweet 3273.wav
# Processed: tweet_1803.wav
# Processed: tweet_6083.wav
# Processed: tweet_2223.wav
# Processed: tweet 3118.wav
# Processed: tweet_1466.wav
# Processed: tweet_6634.wav
# Processed: tweet_1765.wav
# Processed: tweet_1763.wav
# Processed: tweet_1975.wav
# Processed: tweet_2234.wav
# Processed: tweet_2158.wav
# Processed: tweet_848.wav
# Processed: tweet_6243.wav
# Processed: tweet_311.wav
# Processed: tweet_6259.wav
# Processed: tweet_313.wav
# Processed: tweet_2050.wav
# Processed: tweet_2073.wav
# Processed: tweet_680.wav
# Processed: tweet 5616.wav
# Processed: tweet_1642.wav
# Processed: tweet_1707.wav
# Processed: tweet_1401.wav
# Processed: tweet_1605.wav
# Processed: tweet_64.wav
# Processed: tweet_2317.wav
# Processed: tweet_863.wav
# Processed: tweet_337.wav
# Processed: tweet_829.wav
# Processed: tweet_2430.wav
# Processed: tweet_849.wav
# Processed: tweet_791.wav
# Processed: tweet_2178.wav
# Processed: tweet_6311.wav
# Processed: tweet_1916.wav
# Processed: tweet_615.wav
# Processed: tweet 5668.wav
# Processed: tweet_144.wav
# Processed: tweet_5742.wav
# Processed: tweet_1414.wav
# Processed: tweet_955.wav
# Processed: tweet_802.wav
# Processed: tweet_1838.wav
# Processed: tweet 5655.wav
# Processed: tweet_2100.wav
# Processed: tweet_875.wav
# Processed: tweet_834.wav
# Processed: tweet 2917.wav
# Processed: tweet_6654.wav
# Processed: tweet_651.wav
# Processed: tweet_6581.wav
# Processed: tweet_623.wav
# Processed: tweet_1503.wav
# Processed: tweet_1669.wav
# Processed: tweet_5769.wav
# Processed: tweet_579.wav
# Processed: tweet 3359.wav
# Processed: tweet_6043.wav
# Processed: tweet_1109.wav
# Processed: tweet 2909.wav
# Processed: tweet_1458.wav
# Processed: tweet_443.wav
# Processed: tweet_1226.wav
# Processed: tweet 3229.wav
# Processed: tweet 2952.wav
# Processed: tweet_705.wav
# Processed: tweet_2245.wav
# Processed: tweet_1743.wav
# Processed: tweet_1926.wav
# Processed: tweet_2133.wav
# Processed: tweet_1735.wav
# Processed: tweet_95.wav
# Processed: tweet_1774.wav
# Processed: tweet_2198.wav
# Processed: tweet_412.wav
# Processed: tweet_2429.wav
# Processed: tweet_1984.wav
# Processed: tweet_6425.wav
# Processed: tweet_220.wav
# Processed: tweet_332.wav
# Processed: tweet_1343.wav
# Processed: tweet_490.wav
# Processed: tweet 2690.wav
# Processed: tweet_494.wav
# Processed: tweet 3272.wav
# Processed: tweet_6446.wav
# Processed: tweet_1990.wav
# Processed: tweet 3427.wav
# Processed: tweet_5811.wav
# Processed: tweet 3472.wav
# Processed: tweet_1204.wav
# Processed: tweet_1252.wav
# Processed: tweet_6531.wav
# Processed: tweet 2905.wav
# Processed: tweet_1280.wav
# Processed: tweet_1488.wav
# Processed: tweet_254.wav
# Processed: tweet 3321.wav
# Processed: tweet 2966.wav
# Processed: tweet_6041.wav
# Processed: tweet 2719.wav
# Processed: tweet_1954.wav
# Processed: tweet 3301.wav
# Processed: tweet_594.wav
# Processed: tweet_508.wav
# Processed: tweet_1603.wav
# Processed: tweet_1379.wav
# Processed: tweet_5849.wav
# Processed: tweet_1298.wav
# Processed: tweet_139.wav
# Processed: tweet_2431.wav
# Processed: tweet_10.wav
# Processed: tweet_5932.wav
# Processed: tweet 5659.wav
# Processed: tweet_2277.wav
# Processed: tweet_1128.wav
# Processed: tweet_97.wav
# Processed: tweet_860.wav
# Processed: tweet 3213.wav
# Processed: tweet_925.wav
# Processed: tweet_1277.wav
# Processed: tweet_1023.wav
# Processed: tweet_1024.wav
# Processed: tweet 3433.wav
# Processed: tweet_2603.wav
# Processed: tweet_2113.wav
# Processed: tweet_786.wav
# Processed: tweet_2454.wav
# Processed: tweet_2637.wav
# Processed: tweet 3069.wav
# Processed: tweet_1671.wav
# Processed: tweet_1670.wav
# Processed: tweet 3444.wav
# Processed: tweet_6532.wav
# Processed: tweet_960.wav
# Processed: tweet 2987.wav
# Processed: tweet_2584.wav
# Processed: tweet 3516.wav
# Processed: tweet_6137.wav
# Processed: tweet_2463.wav
# Processed: tweet 3467.wav
# Processed: tweet_1310.wav
# Processed: tweet_5898.wav
# Processed: tweet 2990.wav
# Processed: tweet_6609.wav
# Processed: tweet_2065.wav
# Processed: tweet_1427.wav
# Processed: tweet_2374.wav
# Processed: tweet 3417.wav
# Processed: tweet_1888.wav
# Processed: tweet_5837.wav
# Processed: tweet_6447.wav
# Processed: tweet_1117.wav
# Processed: tweet_831.wav
# Processed: tweet_206.wav
# Processed: tweet_6035.wav
# Processed: tweet_6482.wav
# Processed: tweet_45.wav
# Processed: tweet 3137.wav
# Processed: tweet_910.wav
# Processed: tweet_1100.wav
# Processed: tweet 2925.wav
# Processed: tweet_6273.wav
# Processed: tweet_697.wav
# Processed: tweet_292.wav
# Processed: tweet_5841.wav
# Processed: tweet_1809.wav
# Processed: tweet 3304.wav
# Processed: tweet_6637.wav
# Processed: tweet_1529.wav
# Processed: tweet 5716.wav
# Processed: tweet_1512.wav
# Processed: tweet 3011.wav
# Processed: tweet 3415.wav
# Processed: tweet_2553.wav
# Processed: tweet_416.wav
# Processed: tweet_717.wav
# Processed: tweet_1060.wav
# Processed: tweet_76.wav
# Processed: tweet_2091.wav
# Processed: tweet 2897.wav
# Processed: tweet_1395.wav
# Processed: tweet_6018.wav
# Processed: tweet_6703.wav
# Processed: tweet_2097.wav
# Processed: tweet_1160.wav
# Processed: tweet_2108.wav
# Processed: tweet_1871.wav
# Processed: tweet_574.wav
# Processed: tweet_1348.wav
# Processed: tweet_921.wav
# Processed: tweet_964.wav
# Processed: tweet_6284.wav
# Processed: tweet_6699.wav
# Processed: tweet_6229.wav
# Processed: tweet_6573.wav
# Processed: tweet 5699.wav
# Processed: tweet 3474.wav
# Processed: tweet_2472.wav
# Processed: tweet_342.wav
# Processed: tweet_1361.wav
# Processed: tweet_2536.wav
# Processed: tweet_6100.wav
# Processed: tweet_5877.wav
# Processed: tweet_1579.wav
# Processed: tweet_2049.wav
# Processed: tweet_714.wav
# Processed: tweet_645.wav
# Processed: tweet 5701.wav
# Processed: tweet_6328.wav
# Processed: tweet_2486.wav
# Processed: tweet_442.wav
# Processed: tweet_1818.wav
# Processed: tweet_2478.wav
# Processed: tweet_1767.wav
# Processed: tweet_1412.wav
# Processed: tweet_6668.wav
# Processed: tweet_1602.wav
# Processed: tweet_940.wav
# Processed: tweet_2163.wav
# Processed: tweet_713.wav
# Processed: tweet_264.wav
# Processed: tweet_1314.wav
# Processed: tweet_1901.wav
# Processed: tweet 5632.wav
# Processed: tweet_2464.wav
# Processed: tweet_6553.wav
# Processed: tweet_6031.wav
# Processed: tweet_6513.wav
# Processed: tweet_2599.wav
# Processed: tweet 3452.wav
# Processed: tweet_1811.wav
# Processed: tweet_823.wav
# Processed: tweet_2451.wav
# Processed: tweet_1872.wav
# Processed: tweet_1099.wav
# Processed: tweet_269.wav
# Processed: tweet_1008.wav
# Processed: tweet_5988.wav
# Processed: tweet_581.wav
# Processed: tweet_1935.wav
# Processed: tweet_273.wav
# Processed: tweet_647.wav
# Processed: tweet_551.wav
# Processed: tweet 2930.wav
# Processed: tweet 3460.wav
# Processed: tweet 3351.wav
# Processed: tweet_421.wav
# Processed: tweet_116.wav
# Processed: tweet_6718.wav
# Processed: tweet_1283.wav
# Processed: tweet 3076.wav
# Processed: tweet 5608.wav
# Processed: tweet 5705.wav
# Processed: tweet_1679.wav
# Processed: tweet_1738.wav
# Processed: tweet_6495.wav
# Processed: tweet 2738.wav
# Processed: tweet_652.wav
# Processed: tweet_334.wav
# Processed: tweet_6434.wav
# Processed: tweet 5713.wav
# Processed: tweet 3419.wav
# Processed: tweet_5985.wav
# Processed: tweet_1397.wav
# Processed: tweet_650.wav
# Processed: tweet_6222.wav
# Processed: tweet 3362.wav
# Processed: tweet_2098.wav
# Processed: tweet 3259.wav
# Processed: tweet 2892.wav
# Processed: tweet_1921.wav
# Processed: tweet_1987.wav
# Processed: tweet_194.wav
# Processed: tweet 3049.wav
# Processed: tweet_177.wav
# Processed: tweet_613.wav
# Processed: tweet 3410.wav
# Processed: tweet_6305.wav
# Processed: tweet 3000.wav
# Processed: tweet 2955.wav
# Processed: tweet_5981.wav
# Processed: tweet 5672.wav
# Processed: tweet_107.wav
# Processed: tweet_1800.wav
# Processed: tweet_180.wav
# ...
# Processed: tweet_729.wav
# Processed: tweet 3262.wav
# Processed: tweet_1349.wav
# Processed: tweet_653.wav
# Processed: tweet_6289.wav
# Processed: tweet_27.wav
# Processed: tweet_459.wav
# Processed: tweet_749.wav
# Processed: tweet_2341.wav
# Processed: tweet 5617.wav
# Processed: tweet_1216.wav
# Processed: tweet_2068.wav
# Processed: tweet 3363.wav
# Processed: tweet_2570.wav
# Processed: tweet 3503.wav
# Processed: tweet 3152.wav
# Processed: tweet_2432.wav
# Processed: tweet_1778.wav
# Processed: tweet_2096.wav
# Processed: tweet_38.wav
# Processed: tweet_383.wav
# Processed: tweet_1355.wav
# Processed: tweet_2543.wav
# Processed: tweet_413.wav
# Processed: tweet_5933.wav
# Processed: tweet_1683.wav
# Processed: tweet_809.wav
# Processed: tweet_1000.wav
# Processed: tweet_6548.wav
# Processed: tweet_6550.wav
# Processed: tweet_5828.wav
# Processed: tweet_1194.wav
# Processed: tweet_467.wav
# Processed: tweet_2204.wav
# Processed: tweet_6607.wav
# Processed: tweet_2642.wav
# Processed: tweet_1556.wav
# Processed: tweet 3392.wav
# Processed: tweet 5661.wav
# Processed: tweet 3416.wav
# Processed: tweet_801.wav
# Processed: tweet 3286.wav
# Processed: tweet_952.wav
# Processed: tweet_1668.wav
# Processed: tweet_1493.wav
# Processed: tweet_6371.wav
# Processed: tweet_6071.wav
# Processed: tweet_1228.wav
# Processed: tweet_5772.wav
# Processed: tweet_78.wav
# Processed: tweet_1469.wav
# Processed: tweet_5830.wav
# Processed: tweet_537.wav
# Processed: tweet_554.wav
# Processed: tweet 2745.wav
# Processed: tweet_6334.wav
# Processed: tweet_1883.wav
# Processed: tweet_2320.wav
# Processed: tweet_2312.wav
# Processed: tweet_895.wav
# Processed: tweet_6162.wav
# Processed: tweet_517.wav
# Processed: tweet_5757.wav
# Processed: tweet_2051.wav
# Processed: tweet 3413.wav
# Processed: tweet_2002.wav
# Processed: tweet 3237.wav
# Processed: tweet_381.wav
# Processed: tweet_781.wav
# Processed: tweet_1340.wav
# Processed: tweet_105.wav
# Processed: tweet_365.wav
# Processed: tweet_1874.wav
# Processed: tweet_2303.wav
# Processed: tweet_477.wav
# Processed: tweet_1444.wav
# Processed: tweet_805.wav
# Processed: tweet_2197.wav
# Processed: tweet_2443.wav
# Processed: tweet 3054.wav
# Processed: tweet_355.wav
# Processed: tweet_142.wav
# Processed: tweet_6438.wav
# Processed: tweet 3102.wav
# Processed: tweet_434.wav
# Processed: tweet_90.wav
# Processed: tweet_2019.wav
# Processed: tweet_2504.wav
# Processed: tweet__12.wav
# Processed: tweet_6676.wav
# Processed: tweet_777.wav
# Processed: tweet_1417.wav
# Processed: tweet_427.wav
# Processed: tweet 3502.wav
# Processed: tweet 3352.wav
# Processed: tweet_1523.wav
# Processed: tweet_2254.wav
# Processed: tweet_2509.wav
# Processed: tweet_609.wav
# Processed: tweet_2458.wav
# Processed: tweet_523.wav
# Processed: tweet_1832.wav
# Processed: tweet_2153.wav
# Processed: tweet_217.wav
# Processed: tweet_2053.wav
# Processed: tweet 3217.wav
# Processed: tweet_5959.wav
# Processed: tweet_6111.wav
# Processed: tweet_5894.wav
# Processed: tweet 2954.wav
# Processed: tweet_750.wav
# Processed: tweet 3223.wav
# Processed: tweet_6657.wav
# Processed: tweet_1286.wav
# Processed: tweet_2107.wav
# Processed: tweet_5900.wav
# Processed: tweet_1904.wav
# Processed: tweet_929.wav
# Processed: tweet 3483.wav
# Processed: tweet_2334.wav
# Processed: tweet 3142.wav
# Processed: tweet_482.wav
# Processed: tweet_6192.wav
# Processed: tweet_5875.wav
# Processed: tweet_820.wav
# Processed: tweet_1759.wav
# Processed: tweet_2016.wav
# Processed: tweet_5800.wav
# Processed: tweet_93.wav
# Processed: tweet_1697.wav
# Processed: tweet_113.wav
# Processed: tweet_5961.wav
# Processed: tweet_1855.wav
# Processed: tweet_2190.wav
# Processed: tweet_2246.wav
# Processed: tweet_5995.wav
# Processed: tweet 5774.wav
# Processed: tweet_6073.wav
# Processed: tweet_224.wav
# Processed: tweet_471.wav
# Processed: tweet_891.wav
# Processed: tweet_881.wav
# Processed: tweet_1776.wav
# Processed: tweet_5955.wav
# Processed: tweet_595.wav
# Processed: tweet 3297.wav
# Processed: tweet_1447.wav
# Processed: tweet 3174.wav
# Processed: tweet_1255.wav
# Processed: tweet 2660.wav
# Processed: tweet 2774.wav
# Processed: tweet_1923.wav
# Processed: tweet_227.wav
# Processed: tweet_1432.wav
# Processed: tweet_2012.wav
# Processed: tweet_6015.wav
# Processed: tweet_586.wav
# Processed: tweet_1841.wav
# Processed: tweet_1789.wav
# Processed: tweet 2988.wav
# Processed: tweet_6444.wav
# Processed: tweet_6047.wav
# Processed: tweet_746.wav
# Processed: tweet_1804.wav
# Processed: tweet 3211.wav
# Processed: tweet_507.wav
# Processed: tweet 3524.wav
# Processed: tweet_6039.wav
# Processed: tweet_373.wav
# Processed: tweet_1684.wav
# Processed: tweet 3179.wav
# Processed: tweet 3083.wav
# Processed: tweet_1644.wav
# Processed: tweet_1442.wav
# Processed: tweet_1162.wav
# Processed: tweet 3519.wav
# Processed: tweet_2274.wav
# Processed: tweet_6262.wav
# Processed: tweet_6466.wav
# Processed: tweet_1443.wav
# Processed: tweet_6061.wav
# Processed: tweet_1797.wav
# Processed: tweet_999.wav
# Processed: tweet_336.wav
# Processed: tweet_1473.wav
# Processed: tweet_779.wav
# Processed: tweet_2437.wav
# Processed: tweet_917.wav
# Processed: tweet_1318.wav
# Processed: tweet_1483.wav
# Processed: tweet_2154.wav
# Processed: tweet_2247.wav
# Processed: tweet_6088.wav
# Processed: tweet 2946.wav
# Processed: tweet_6219.wav
# Processed: tweet_1750.wav
# Processed: tweet_1695.wav
# Processed: tweet_1815.wav
# Processed: tweet_6385.wav
# Processed: tweet_6314.wav
# Processed: tweet_1893.wav
# Processed: tweet_2109.wav
# Processed: tweet_1944.wav
# Processed: tweet_1691.wav
# Processed: tweet 3418.wav
# Processed: tweet_6693.wav
# Processed: tweet_1607.wav
# Processed: tweet 2957.wav
# Processed: tweet_447.wav
# Processed: tweet_5787.wav
# Processed: tweet 3399.wav
# Processed: tweet_6567.wav
# Processed: tweet_6661.wav
# Processed: tweet 3348.wav
# Processed: tweet_1113.wav
# Processed: tweet 3261.wav
# Processed: tweet_6647.wav
# Processed: tweet_158.wav
# Processed: tweet_444.wav
# Processed: tweet_1758.wav
# Processed: tweet_956.wav
# Processed: tweet_1210.wav
# Processed: tweet_6274.wav
# Processed: tweet 2895.wav
# Processed: tweet_736.wav
# Processed: tweet_284.wav
# Processed: tweet_1942.wav
# Processed: tweet_792.wav
# Processed: tweet 3438.wav
# Processed: tweet 3390.wav
# Processed: tweet_133.wav
# Processed: tweet_1415.wav
# Processed: tweet 3219.wav
# Processed: tweet_361.wav
# Processed: tweet_2048.wav
# Processed: tweet_1732.wav
# Processed: tweet_371.wav
# Processed: tweet_6272.wav
# Processed: tweet_6032.wav
# Processed: tweet_663.wav
# Processed: tweet 3407.wav
# Processed: tweet_1433.wav
# Processed: tweet_793.wav
# Processed: tweet 3177.wav
# Processed: tweet_885.wav
# Processed: tweet_1689.wav
# Processed: tweet_130.wav
# Processed: tweet 2982.wav
# Processed: tweet_1179.wav
# Processed: tweet_2444.wav
# Processed: tweet_6633.wav
# Processed: tweet_1834.wav
# Processed: tweet_1884.wav
# Processed: tweet_14.wav
# Processed: tweet_5869.wav
# Processed: tweet_6556.wav
# Processed: tweet_778.wav
# Processed: tweet_2551.wav
# Processed: tweet_2577.wav
# Processed: tweet_954.wav
# Processed: tweet 2998.wav
# Processed: tweet_6072.wav
# Processed: tweet_2490.wav
# Processed: tweet_1057.wav
# Processed: tweet_238.wav
# Processed: tweet 3185.wav
# Processed: tweet 2934.wav
# Processed: tweet_2281.wav
# Processed: tweet_6426.wav
# Processed: tweet_1089.wav
# Processed: tweet_6597.wav
# Processed: tweet_5868.wav
# Processed: tweet_585.wav
# Processed: tweet_6160.wav
# Processed: tweet_6265.wav
# Processed: tweet_923.wav
# Processed: tweet_431.wav
# Processed: tweet_1372.wav
# Processed: tweet_1461.wav
# Processed: tweet_2313.wav
# Processed: tweet_1135.wav
# Processed: tweet 2971.wav
# Processed: tweet 3155.wav
# Processed: tweet_610.wav
# Processed: tweet_6626.wav
# Processed: tweet_1853.wav
# Processed: tweet_709.wav
# Processed: tweet 5776.wav
# Processed: tweet_6179.wav
# Processed: tweet_1009.wav
# Processed: tweet_1666.wav
# Processed: tweet_978.wav
# Processed: tweet_128.wav
# Processed: tweet_1909.wav
# Processed: tweet_5924.wav
# Processed: tweet_1077.wav
# Processed: tweet_1025.wav
# Processed: tweet_1896.wav
# Processed: tweet_1657.wav
# Processed: tweet 3283.wav
# Processed: tweet_1828.wav
# Processed: tweet_2124.wav
# Processed: tweet_6168.wav
# Processed: tweet_2592.wav
# Processed: tweet 2958.wav
# Processed: tweet_41.wav
# Processed: tweet 3442.wav
# Processed: tweet_965.wav
# Processed: tweet_6310.wav
# Processed: tweet_1080.wav
# Processed: tweet_5739.wav
# Processed: tweet_2411.wav
# Processed: tweet_884.wav
# Processed: tweet_6131.wav
# Processed: tweet_6163.wav
# Processed: tweet_1229.wav
# Processed: tweet_797.wav
# Processed: tweet 3067.wav
# Processed: tweet_1140.wav
# Processed: tweet_1957.wav
# Processed: tweet_2380.wav
# Processed: tweet_1796.wav
# Processed: tweet_5993.wav
# Processed: tweet_2623.wav
# Processed: tweet_1636.wav
# Processed: tweet_348.wav
# Processed: tweet_6523.wav
# Processed: tweet_1637.wav
# Processed: tweet_6472.wav
# Processed: tweet_589.wav
# Processed: tweet_6569.wav
# Processed: tweet_125.wav
# Processed: tweet_2563.wav
# Processed: tweet_29.wav
# Processed: tweet_2206.wav
# Processed: tweet 5706.wav
# Processed: tweet_6096.wav
# Processed: tweet 3411.wav
# Processed: tweet 5644.wav
# Processed: tweet_1924.wav
# Processed: tweet_578.wav
# Processed: tweet_5876.wav
# Processed: tweet_2237.wav
# Processed: tweet 3126.wav
# Processed: tweet_6673.wav
# Processed: tweet_2046.wav
# Processed: tweet_2266.wav
# Processed: tweet 3409.wav
# Processed: tweet_1195.wav
# Processed: tweet_5895.wav
# Processed: tweet_760.wav
# Processed: tweet 2726.wav
# Processed: tweet_719.wav
# Processed: tweet_1168.wav
# Processed: tweet_545.wav
# Processed: tweet_1502.wav
# Processed: tweet 3520.wav
# Processed: tweet_6388.wav
# Processed: tweet_800.wav
# Processed: tweet 3337.wav
# Processed: tweet_6255.wav
# Processed: tweet_5803.wav
# Processed: tweet_198.wav
# Processed: tweet 3093.wav
# Processed: tweet_6269.wav
# Processed: tweet_597.wav
# Processed: tweet 3430.wav
# Processed: tweet_6319.wav
# Processed: tweet_6624.wav
# Processed: tweet_5791.wav
# Processed: tweet_1837.wav
# Processed: tweet_6455.wav
# Processed: tweet_5833.wav
# Processed: tweet_1665.wav
# Processed: tweet_1939.wav
# Processed: tweet_183.wav
# Processed: tweet_196.wav
# Processed: tweet 3508.wav
# Processed: tweet_192.wav
# Processed: tweet_2295.wav
# Processed: tweet_46.wav
# Processed: tweet_1351.wav
# Processed: tweet_1964.wav
# Processed: tweet_6004.wav
# Processed: tweet_6158.wav
# Processed: tweet_782.wav
# Processed: tweet_2645 - (2).wav
# Processed: tweet 2956.wav
# Processed: tweet 3035.wav
# Processed: tweet_6353.wav
# Processed: tweet_2643.wav
# Processed: tweet_5911.wav
# Processed: tweet 5691.wav
# Processed: tweet_226.wav
# Processed: tweet_1192.wav
# Processed: tweet_1714.wav
# Processed: tweet_6089.wav
# Processed: tweet_88.wav
# Processed: tweet_2278.wav
# Processed: tweet_375.wav
# Processed: tweet_1973.wav
# Processed: tweet_2031.wav
# Processed: tweet_1571.wav
# Processed: tweet_6254.wav
# Processed: tweet_2174.wav
# Processed: tweet_513.wav
# Processed: tweet_1768.wav
# Processed: tweet_6428.wav
# Processed: tweet 3322.wav
# Processed: tweet_937.wav
# Processed: tweet_1833.wav
# Processed: tweet 5642.wav
# Processed: tweet_1093.wav
# Processed: tweet 2911.wav
# Processed: tweet_2023.wav
# Processed: tweet_2639.wav
# Processed: tweet_6197.wav
# Processed: tweet_1155.wav
# Processed: tweet_5970.wav
# Processed: tweet_75.wav
# Processed: tweet_188.wav
# Processed: tweet_2526.wav
# Processed: tweet_861.wav
# Processed: tweet 3264.wav
# Processed: tweet_5829.wav
# Processed: tweet_6589.wav
# Processed: tweet_2103.wav
# Processed: tweet 3275.wav
# Processed: tweet 3381.wav
# Processed: tweet 2695.wav
# Processed: tweet_6114.wav
# Processed: tweet_6124.wav
# Processed: tweet 3156.wav
# Processed: tweet_966.wav
# Processed: tweet_528.wav
# Processed: tweet_6448.wav
# Processed: tweet 3239.wav
# Processed: tweet_1211.wav
# Processed: tweet_69.wav
# Processed: tweet_79.wav
# Processed: tweet_2193.wav
# Processed: tweet_1630.wav
# Processed: tweet_6279.wav
# Processed: tweet_2434.wav
# Processed: tweet_1028.wav
# Processed: tweet 2716.wav
# Processed: tweet_63.wav
# Processed: tweet 3030.wav
# Processed: tweet_1787.wav
# Processed: tweet 3378.wav
# Processed: tweet_6067.wav
# Processed: tweet_5963.wav
# Processed: tweet 3136.wav
# Processed: tweet 3183.wav
# Processed: tweet_561.wav
# Processed: tweet 3098.wav
# Processed: tweet_2137.wav
# Processed: tweet_2406.wav
# Processed: tweet_2328.wav
# Processed: tweet_122.wav
# Processed: tweet_2578.wav
# Processed: tweet_761.wav
# Processed: tweet_22.wav
# Processed: tweet_1337.wav
# Processed: tweet_1791.wav
# Processed: tweet_391.wav
# Processed: tweet_1540.wav
# Processed: tweet 3159.wav
# Processed: tweet_6267.wav
# Processed: tweet_403.wav
# Processed: tweet_2129.wav
# Processed: tweet_190.wav
# Processed: tweet_5758.wav
# Processed: tweet_2410.wav
# Processed: tweet_2515.wav
# Processed: tweet_2139.wav
# Processed: tweet_602.wav
# Processed: tweet_6538.wav
# Processed: tweet_1854.wav
# Processed: tweet_1690.wav
# Processed: tweet_6714.wav
# Processed: tweet_5944.wav
# Processed: tweet 5639.wav
# Processed: tweet_5745.wav
# Processed: tweet_2022.wav
# Processed: tweet_473.wav
# Processed: tweet_1249.wav
# Processed: tweet 2709.wav
# Processed: tweet_2225.wav
# Processed: tweet_593.wav
# Processed: tweet_5759.wav
# Processed: tweet 5670.wav
# Processed: tweet_1568.wav
# Processed: tweet_6333.wav
# Processed: tweet_6130.wav
# Processed: tweet_2601.wav
# Processed: tweet 2675.wav
# Processed: tweet_700.wav
# Processed: tweet_2630.wav
# Processed: tweet_1696.wav
# Processed: tweet_6066.wav
# Processed: tweet_5948.wav
# Processed: tweet_6494.wav
# Processed: tweet_136.wav
# Processed: tweet_6432.wav
# Processed: tweet_6308.wav
# Processed: tweet_6362.wav
# Processed: tweet_2080.wav
# Processed: tweet_341.wav
# Processed: tweet_8046.wav
# Processed: tweet 3205.wav
# Processed: tweet_2283.wav
# Processed: tweet_5799.wav
# Processed: tweet_1126.wav
# Processed: tweet_1339.wav
# Processed: tweet_1720.wav
# Processed: tweet_2319.wav
# Processed: tweet_1686.wav
# Processed: tweet_2617.wav
# Processed: tweet_369.wav
# Processed: tweet_163.wav
# Processed: tweet_759.wav
# Processed: tweet_5844.wav
# Processed: tweet_290.wav
# Processed: tweet_2066.wav
# Processed: tweet_319.wav
# Processed: tweet 2947.wav
# Processed: tweet_1151.wav
# Processed: tweet_1173.wav
# Processed: tweet_1227.wav
# Processed: tweet_564.wav
# Processed: tweet 2676.wav
# Processed: tweet_1953.wav
# Processed: tweet_1898.wav
# Processed: tweet_2262.wav
# Processed: tweet 5779.wav
# Processed: tweet_6373.wav
# Processed: tweet_1634.wav
# Processed: tweet_1754.wav
# Processed: tweet_2466.wav
# Processed: tweet_959.wav
# Processed: tweet_2489.wav
# Processed: tweet_324.wav
# Processed: tweet_1929.wav
# Processed: tweet_530.wav
# Processed: tweet_1646.wav
# Processed: tweet_1606.wav
# Processed: tweet_439.wav
# Processed: tweet_6202.wav
# Processed: tweet_179.wav
# Processed: tweet_1863.wav
# Processed: tweet 2756.wav
# Processed: tweet 3087.wav
# Processed: tweet_100.wav
# Processed: tweet 3125.wav
# Processed: tweet_996.wav
# Processed: tweet 3198.wav
# Processed: tweet 3104.wav
# Processed: tweet_1014.wav
# Processed: tweet_1457.wav
# Processed: tweet 3447.wav
# Processed: tweet_6484.wav
# Processed: tweet_56.wav
# Processed: tweet_5891.wav
# Processed: tweet_422.wav
# Processed: tweet 5623.wav
# Processed: tweet_8221.wav
# Processed: tweet_1703.wav
# Processed: tweet_879.wav
# Processed: tweet 5721.wav
# Processed: tweet 3517.wav
# Processed: tweet 3172.wav
# Processed: tweet 3385.wav
# Processed: tweet_2296.wav
# Processed: tweet_282.wav
# Processed: tweet_6628.wav
# Processed: tweet_584.wav
# Processed: tweet_496.wav
# Processed: tweet_218.wav
# Processed: tweet_1422.wav
# Processed: tweet_244.wav
# Processed: tweet_2299.wav
# Processed: tweet 3377.wav
# Processed: tweet_755.wav
# Processed: tweet 3477.wav
# Processed: tweet_5938.wav
# Processed: tweet 3305.wav
# Processed: tweet_1989.wav
# Processed: tweet_1533.wav
# Processed: tweet_6185.wav
# Processed: tweet 3091.wav
# Processed: tweet 2743.wav
# Processed: tweet_689.wav
# Processed: tweet_5953.wav
# Processed: tweet 3016.wav
# Processed: tweet_94.wav
# Processed: tweet 5606.wav
# Processed: tweet_6207.wav
# Processed: tweet_542.wav
# Processed: tweet_6430.wav
# Processed: tweet_1597.wav
# Processed: tweet_ 2.wav
# Processed: tweet_6161.wav
# Processed: tweet_985.wav
# Processed: tweet_2575.wav
# Processed: tweet_452.wav
# Processed: tweet_1639.wav
# Processed: tweet_692.wav
# Processed: tweet_1300.wav
# Processed: tweet_6374.wav
# Processed: tweet_5865.wav
# Processed: tweet 3339.wav
# Processed: tweet_6065.wav
# Processed: tweet_1352.wav
# Processed: tweet_1485.wav
# Processed: tweet_2396.wav
# Processed: tweet_6521.wav
# Processed: tweet_908.wav
# Processed: tweet_279.wav
# Audio preprocessing complete! All files are ready for Tacotron 2.

# %% [markdown]
# ## Merged audio and transcript

# %%
audio_folder = "/content/drive/MyDrive/NLP_DS/final_audio"
transcript_folder = "/content/drive/MyDrive/NLP_DS/tweet_transcript"
output_csv = "/content/drive/MyDrive/NLP_DS/merge.csv"


def extract_number(filename):
    match = re.search(r'\d+', filename)
    return match.group() if match else None

audio_files = os.listdir(audio_folder)
transcript_files = os.listdir(transcript_folder)

audio_map = {}
for audio in audio_files:
    num = extract_number(audio)
    if num:
        if num in audio_map:
            audio_map[num].append(audio)
        else:
            audio_map[num] = [audio]

transcript_map = {extract_number(transcript): transcript for transcript in transcript_files if extract_number(transcript)}

mapped_data = []
for num, audios in audio_map.items():
    if num in transcript_map:
        transcript_file = transcript_map[num]
        for i, audio in enumerate(audios):
            if i > 0:
                new_transcript = f"{num}_copy{i}.txt"
                shutil.copy(os.path.join(transcript_folder, transcript_file), os.path.join(transcript_folder, new_transcript))
                mapped_data.append([num, audio, new_transcript])
            else:
                mapped_data.append([num, audio, transcript_file])
    else:
        mapped_data.append([num, audios[0], None])

df = pd.DataFrame(mapped_data, columns=["Unique_ID", "Audio_File", "Transcript_File"])

df.to_csv(output_csv, index=False)
print("Audio and transcript mapping completed and saved to CSV!")
# Out:
# Audio and transcript mapping completed and saved to CSV!

# %%
df=pd.read_csv("/content/drive/MyDrive/NLP_DS/merge.csv")

# %%
df["Audio_Path"] = "/content/drive/MyDrive/NLP_DS/final_audio/" + df["Audio_File"]
df["Transcript_Path"] = "/content/drive/MyDrive/NLP_DS/tweet_transcript/" + df["Transcript_File"]

# %%
df.head()
# Out:
#    Unique_ID      Audio_File Transcript_File  \
# 0       5945  tweet_5945.wav   tweet5945.txt
# 1        598   tweet_598.wav    tweet598.txt
# 2        161   tweet_161.wav    tweet161.txt
# 3       3210  tweet 3210.wav   tweet3210.txt
# 4        982   tweet_982.wav    tweet982.txt
#
#                                           Audio_Path  \
# 0  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 1  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 2  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 3  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 4  /content/drive/MyDrive/NLP_DS/final_audio/twee...
#
#                                      Transcript_Path
# 0  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 1  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 2  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 3  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 4  /content/drive/MyDrive/NLP_DS/tweet_transcript...

# %%
df.shape
# Out:
# (4538, 5)

# %%
df=df.drop(columns=["Audio_File","Transcript_File"])

# %% [markdown]
# ## Preprocessing Transcript

# %%
def read_transcript(path):
    if os.path.exists(path):
        try:
            with open(path, "r", encoding="utf-8") as file:
                return file.read().strip()
        except Exception as e:
            return f"Error: {str(e)}"
    return "File Not Found"

num_cores = os.cpu_count()
df["transcript"] = Parallel(n_jobs=num_cores)(
    delayed(read_transcript)(path) for path in df["Transcript_Path"]
)

print(df.head())
# Out:
#    Unique_ID                                         Audio_Path  \
# 0       5945  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 1        598  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 2        161  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 3       3210  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 4        982  /content/drive/MyDrive/NLP_DS/final_audio/twee...
#
#                                      Transcript_Path  \
# 0  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 1  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 2  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 3  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 4  /content/drive/MyDrive/NLP_DS/tweet_transcript...
#
#                                           transcript
# 0  <s> chakula chetu   a book on indigenous recip...
# 1  <s> polisi amuua mpenziwe  afisa wa polisi amu...
# 2  <s> jamaa ni mtafutaji halisi  weeeeeee kumbe ...
# 3  <s> vodka na bei yake imekubali  ama aje wadau...
# 4  <s> mauti ya familia  mama na wanawe watatu wa...

# %%
df.head()
# Out:
#    Unique_ID                                         Audio_Path  \
# 0       5945  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 1        598  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 2        161  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 3       3210  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 4        982  /content/drive/MyDrive/NLP_DS/final_audio/twee...
#
#                                      Transcript_Path  \
# 0  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 1  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 2  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 3  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 4  /content/drive/MyDrive/NLP_DS/tweet_transcript...
#
#                                           transcript
# 0  <s> chakula chetu   a book on indigenous recip...
# 1  <s> polisi amuua mpenziwe  afisa wa polisi amu...
# 2  <s> jamaa ni mtafutaji halisi  weeeeeee kumbe ...
# 3  <s> vodka na bei yake imekubali  ama aje wadau...
# 4  <s> mauti ya familia  mama na wanawe watatu wa...

# %%
def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"<s>", "", text)  # Remove <s> markers
    text = re.sub(r"\(tweet_\d+\)", "", text)  # Remove tweet IDs
    text = re.sub(r"[^\w\s]", "", text)  # Remove punctuation except spaces
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text
df["transcript"] = df["transcript"].apply(clean_text)

# %%
df.head()
# Out:
#    Unique_ID                                         Audio_Path  \
# 0       5945  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 1        598  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 2        161  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 3       3210  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 4        982  /content/drive/MyDrive/NLP_DS/final_audio/twee...
#
#                                      Transcript_Path  \
# 0  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 1  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 2  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 3  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 4  /content/drive/MyDrive/NLP_DS/tweet_transcript...
#
#                                           transcript
# 0  chakula chetu a book on indigenous recipes fro...
# 1  polisi amuua mpenziwe afisa wa polisi amuua mp...
# 2  jamaa ni mtafutaji halisi weeeeeee kumbe dolph...
# 3        vodka na bei yake imekubali ama aje wadau s
# 4  mauti ya familia mama na wanawe watatu wafarik...

# %%
df.to_csv("/content/drive/MyDrive/NLP_DS/tts_dataset.csv")

# %%
df.head()
# Out:
#    Unique_ID                                         Audio_Path  \
# 0       5945  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 1        598  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 2        161  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 3       3210  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 4        982  /content/drive/MyDrive/NLP_DS/final_audio/twee...
#
#                                      Transcript_Path  \
# 0  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 1  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 2  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 3  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 4  /content/drive/MyDrive/NLP_DS/tweet_transcript...
#
#                                           transcript
# 0  chakula chetu a book on indigenous recipes fro...
# 1  polisi amuua mpenziwe afisa wa polisi amuua mp...
# 2  jamaa ni mtafutaji halisi weeeeeee kumbe dolph...
# 3        vodka na bei yake imekubali ama aje wadau s
# 4  mauti ya familia mama na wanawe watatu wafarik...

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Convert transcript to phonemes

# %%
phoneme_file = "/content/drive/MyDrive/NLP_DS/kencorpus.phone"
with open(phoneme_file, "r") as f:
    phoneme_list = [line.strip() for line in f.readlines()]

swahili_phoneme_map = {
    'a': 'AA', 'b': 'B', 'ch': 'CH', 'd': 'D', 'dh': 'DH', 'e': 'EH', 'ee': 'EE',
    'f': 'F', 'g': 'G', 'gh': 'GH', 'h': 'HH', 'i': 'IH', 'ii': 'II', 'j': 'JH',
    'k': 'K', 'kh': 'KH', 'l': 'L', 'm': 'M', 'mb': 'MB', 'n': 'N', 'nd': 'ND',
    'nj': 'NJ', 'ng': 'NG', "ng'": "NG'", 'ny': 'NY', 'nz': 'NZ', 'o': 'OH',
    'oo': 'OO', 'p': 'P', 'r': 'R', 's': 'S', 'sh': 'SH', 't': 'T', 'th': 'TH',
    'u': 'UH', 'uu': 'UU', 'v': 'V', 'w': 'W', 'y': 'Y', 'z': 'Z'
}

def swahili_to_phoneme(word):
    phonemes = []
    i = 0
    while i < len(word):
        if i + 1 < len(word) and word[i:i+2] in swahili_phoneme_map:
            phonemes.append(swahili_phoneme_map[word[i:i+2]])
            i += 2
        elif word[i] in swahili_phoneme_map:
            phonemes.append(swahili_phoneme_map[word[i]])
            i += 1
        else:
            phonemes.append(word[i])  # Keep unknown letters as they are
            i += 1
    return ' '.join(phonemes)

file_path = "/content/drive/MyDrive/NLP_DS/tts_dataset.csv"
df = pd.read_csv(file_path)
if 'transcript' not in df.columns:
    raise ValueError("The dataset does not contain a 'transcript' column. Please check the file.")

df['phonemes'] = df['transcript'].astype(str).apply(swahili_to_phoneme)

df.to_csv(file_path, index=False)

# %% [markdown]
# ## convert phonemes to phonemes_id

# %%
phoneme_file = "/content/drive/MyDrive/NLP_DS/kencorpus.phone"
with open(phoneme_file, "r") as f:
    phoneme_list = [line.strip() for line in f if line.strip()]

# %%
phoneme_to_id = {phoneme: idx for idx, phoneme in enumerate(phoneme_list)}

# %%
def convert_to_ids(phoneme_str):
    return [phoneme_to_id[ph] for ph in phoneme_str.split() if ph in phoneme_to_id]
df['phoneme_ids'] = df['phonemes'].apply(convert_to_ids)

# %% [markdown]
# ## Final preprocessed dataframe

# %%
df=pd.read_csv("/content/drive/MyDrive/NLP_DS/tts_dataset.csv")

# %%
df=df.drop(columns=["mel_spec"])

# %%
df.head()
# Out:
#    Unnamed: 0  Unique_ID                                         Audio_Path  \
# 0           0       5945  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 1           1        598  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 2           2        161  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 3           3       3210  /content/drive/MyDrive/NLP_DS/final_audio/twee...
# 4           4        982  /content/drive/MyDrive/NLP_DS/final_audio/twee...
#
#                                      Transcript_Path  \
# 0  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 1  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 2  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 3  /content/drive/MyDrive/NLP_DS/tweet_transcript...
# 4  /content/drive/MyDrive/NLP_DS/tweet_transcript...
#
#                                           transcript  \
# 0  chakula chetu a book on indigenous recipes fro...
# 1  polisi amuua mpenziwe afisa wa polisi amuua mp...
# 2  jamaa ni mtafutaji halisi weeeeeee kumbe dolph...
# 3        vodka na bei yake imekubali ama aje wadau s
# 4  mauti ya familia mama na wanawe watatu wafarik...
#
#                                             phonemes  \
# 0  CH AA K UH L AA   CH EH T UH   AA   B OO K   O...
# 1  P OH L IH S IH   AA M UU AA   M P EH NZ IH W E...
# 2  JH AA M AA AA   N IH   M T AA F UH T AA JH IH ...
# 3  V OH D K AA   N AA   B EH IH   Y AA K EH   IH ...
# 4  M AA UH T IH   Y AA   F AA M IH L IH AA   M AA...
#
#                                          phoneme_ids
# 0  [3, 0, 15, 37, 17, 0, 3, 7, 34, 37, 0, 2, 27, ...
# 1  [29, 28, 17, 13, 31, 13, 0, 18, 36, 0, 18, 29,...
# 2  [14, 0, 18, 0, 0, 20, 13, 18, 34, 0, 8, 37, 34...
# 3  [38, 28, 4, 15, 0, 20, 0, 2, 7, 13, 40, 0, 15,...
# 4  [18, 0, 37, 34, 13, 40, 0, 8, 0, 18, 13, 17, 1...

# %% [markdown]
# ## Converting Audio to Mel Spectorgram and saved as npy

# %%
def extract_and_save(audio_path, output_dir, sr=22050, n_mels=80, hop_length=256, win_length=1024):

    audio, sr = librosa.load(audio_path, sr=sr)

    mel_spec = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=n_mels,hop_length=hop_length, win_length=win_length)
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

    base_name = os.path.basename(audio_path)
    file_name = os.path.splitext(base_name)[0] + "_mel.npy"
    file_path = os.path.join(output_dir, file_name)

    np.save(file_path, mel_spec_db)
    print(f'Done for {audio_path}')
    return file_path

output_dir = "/content/drive/MyDrive/NLP_DS/mel_spec"
os.makedirs(output_dir, exist_ok=True)

df['mel_spec_path'] = Parallel(n_jobs=-1)(
    delayed(extract_and_save)(path, output_dir) for path in df['Audio_Path']
)

df.to_csv('/content/drive/MyDrive/NLP_DS/tts_dataset.csv', index=False)
print("DataFrame saved to CSV with mel spectrogram paths.")
# Out:
# DataFrame saved to CSV with mel spectrogram paths.

# %%
df.to_pickle("full_data.pkl")
from IPython.display import FileLink
FileLink("full_data.pkl")
# Out:
# /content/full_data.pkl
